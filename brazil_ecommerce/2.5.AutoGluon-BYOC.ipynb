# %% [markdown]
# # [Module 2.2] AutoGluon Tabular 모델을 BYOC(Bring Your Own Container) 로 구현하기
#
# 아래 노트북은 Bring Your Own Container(BYOC)를 구현 했습니다.
# **아래 공식 예제의 코드와 거의 유사하지만, 데이타는 다릅니다.** 여러분도 데이터만 교체하여 사용하실 수 있습니다.
#
#
# - AutoGluon Bring Your Own Container (BYOC) 예제
#     - https://github.com/aws/amazon-sagemaker-examples/tree/master/advanced_functionality/autogluon-tabular
# - AutoGluon 공식 Lab Git
#     - [AutoGluon](https://github.com/awslabs/autogluon)
#
# 이 노트북은 아래와 같은 작업을 합니다.
# - 훈련 및 추론의 다커 이미지를 로컬에서 빌딩하고, ECR에 등록
# - 훈련, 테스트 데이터 로딩 및 S3에 업로드
# - 오토글로온 하이퍼 파라미터 설정
# - 오토글루온 모델 훈련
#     - 로컬 모드 및 세이지 메이커 호스트 모드 중 선택
# - 세이지 메이커 모델 생성
# - 배치 트랜스폼
# - 실시간 엔드포인트 생성
# - 추론
#
# **편의상 원본의 영문으로 된 것을 그대로 사용하고, 필요시에 한글로 설명이 있습니다.**
#
# ##### 이 노트북은 소요 시간이 약 30 분 걸립니다.
#
# ### 이 노트북은 SageMaker Studio에서는 Docker 부분에서 동작하지 않습니다.
# - SageMakere Studio Notebook 이 Docker 안에서 실행이 되기에, docker 명령어를 사용할 수 없습니다.
# - SageMaker Studio 에서 다커 빌드를 위해서는 아래 URL을 참조 해주세요.
#     - https://github.com/aws-samples/sagemaker-studio-image-build-cli
#
# #### 다커에 익숙지 않으신 분은 아래를 확인 해주세요.
# - Hello docker (for 데이터 과학자 및 개발자 by 강성문)
# - https://github.com/mullue/hello-docker/blob/master/hello_docker.ipynb

# %% [markdown]
# ## 커널 선택
#
# 세이지 메이커 노트북을 사용하신다면, 커널 "conda_mxnet_p36" 를 선택하세요.

# %% [markdown]
# 아래는 [docker-compose](https://docs.docker.com/compose/) 를 확인해서 없으면 설치하는 shell 입니다. docker-compose는 로컬에서 다커를 정의하고 실행을 할 수 있는 편리한 환경을 제공합니다.

# %%
# Make sure docker compose is set up properly for local mode
# !./setup.sh
# Out:
# The user has root access.
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %%
import os
import boto3
import sagemaker
from time import sleep
from collections import Counter
import numpy as np
import pandas as pd
from sagemaker import get_execution_role, local, Model, utils, s3
from sagemaker.estimator import Estimator
from sagemaker.predictor import Predictor
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import StringDeserializer
from sklearn.metrics import accuracy_score, classification_report
from IPython.core.display import display, HTML
from IPython.core.interactiveshell import InteractiveShell

# Print settings
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 10)

# Account/s3 setup
session = sagemaker.Session()
local_session = local.LocalSession()
bucket = session.default_bucket()
prefix = 'sagemaker/autogluon-tabular'
region = session.boto_region_name
role = get_execution_role()
client = session.boto_session.client(
    "sts", region_name=region, endpoint_url=utils.sts_regional_endpoint(region)
    )
account = client.get_caller_identity()['Account']

registry_uri_training = sagemaker.image_uris.retrieve('mxnet', region, version= '1.6.0', py_version='py3', instance_type='ml.m5.2xlarge', image_scope='training')
registry_uri_inference = sagemaker.image_uris.retrieve('mxnet', region, version= '1.6.0', py_version='py3', instance_type='ml.m5.2xlarge', image_scope='inference')
ecr_uri_prefix = account +'.'+'.'.join(registry_uri_training.split('/')[0].split('.')[1:])

# %% [markdown]
# ### 다커 이미지 로컬 빌딩 및 ECR 에 등록

# %% [markdown]
# 훈련 및 추론은 위한 사용자 정의 다커 이미지를 로컬에서 빌딩하고, ECR에 등록합니다.
# 아래는 훈련과 추론의 다커 이미지 이름을 기술합니다.

# %%
training_algorithm_name = 'autogluon-sagemaker-training-pdt'
inference_algorithm_name = 'autogluon-sagemaker-inference-pdt'

# %%
print(f"account: {account}")
print(f"region: {region}")
print(f"ecr_uri_prefix: {ecr_uri_prefix}")
print(f"accouunt id having the mxnet built-in training image: \n{registry_uri_training.split('/')[0].split('.')[0]}")
print(f"the mxnet built-in training image: \n{registry_uri_training}")
# Out:
# account: 057716757052
# region: ap-northeast-2
# ecr_uri_prefix: 057716757052.dkr.ecr.ap-northeast-2.amazonaws.com
# accouunt id having the mxnet built-in training image:
# 763104351884
# the mxnet built-in training image:
# 763104351884.dkr.ecr.ap-northeast-2.amazonaws.com/mxnet-training:1.6.0-cpu-py3

# %% [markdown]
# ```build_push_training.sh``` 에 아래와 같은 파라미터를 제공 합니다.
# ```
# account: 057716757052
# region: ap-northeast-2
# ecr_uri_prefix: 057716757052.dkr.ecr.ap-northeast-2.amazonaws.com
# accouunt id having the mxnet built-in training image:
# 763104351884
# the mxnet built-in training image:
# 763104351884.dkr.ecr.ap-northeast-2.amazonaws.com/mxnet-training:1.6.0-cpu-py3
# ```
# shell 파일은 아래와 같은 작업을 합니다.
# - ECR에 위에서 명시한 알고리즘(에: autogluon-sagemaker-training-pdt) 의 리파지토리가 있는지 확인하고 없으면 생성 합니다.
# - ECR의 알고리즘이 소유하고 있는 계정에 로그인합니다.
# - ECR의 the mxnet built-in training image 를 가지고 있는 계정에 로그인 합니다.
# - container-training/Dockerfile.training 의 Dockerfile 을 이용하여 다커 이미지를 로컬에서 빌딩합니다.
# - 로컬에서 빌딩된 다커 이미지를 ECR에 등록(Push) 합니다.

# %% [markdown]
# ```
# !/bin/bash ./container-training/build_push_training.sh {account} {region} {training_algorithm_name} {ecr_uri_prefix} {registry_uri_training.split('/')[0].split('.')[0]} {registry_uri_training}
# ```
# ```
# #!/bin/bash
#
# # Get account
# account=${1}
#
# # Get the region defined in the current configuration
# region=${2:-us-east-1}
#
# # The name of our algorithm
# algorithm_name=${3:-sagemaker-autogluon-training}
#
# uri_prefix=${4}
# fullname="${uri_prefix}/${algorithm_name}:latest"
#
# # Get the registry id
# registry_id=${5}
# registry_uri=${6}
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --region ${region} --repository-names "${algorithm_name}" > /dev/null 2>&1
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --region ${region} --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
# $(aws ecr get-login --registry-ids ${registry_id} --region ${region} --no-include-email)
#
# # Build the docker image, tag with full name and then push it to ECR
# docker build -t ${algorithm_name} -f container-training/Dockerfile.training . --build-arg REGISTRY_URI=${registry_uri}
# docker tag ${algorithm_name} ${fullname}
# docker push ${fullname}
# ```

# %% [markdown]
# #### 아래는 훈련과 추론의 다커 이미지 생성 및 ECR 등록의 실제 명령어 입니다. 결과에 **에러** 가 없는지 확인을 꼭 하시기 바랍니다.

# %%
print("##### Build Training Image ###########")
# !/bin/bash ./container-training/build_push_training.sh {account} {region} {training_algorithm_name} {ecr_uri_prefix} {registry_uri_training.split('/')[0].split('.')[0]} {registry_uri_training}
print("##### Build Inference Image ###########")
# !/bin/bash ./container-inference/build_push_inference.sh {account} {region} {inference_algorithm_name} {ecr_uri_prefix} {registry_uri_training.split('/')[0].split('.')[0]} {registry_uri_inference}
# Out:
# ##### Build Training Image ###########
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Sending build context to Docker daemon  153.4MB
# Step 1/12 : ARG REGISTRY_URI
# Step 2/12 : FROM ${REGISTRY_URI}
#  ---> 148136370d72
# Step 3/12 : RUN pip install autogluon
#  ---> Using cache
#  ---> fbf27e47c5a1
# Step 4/12 : RUN pip install PrettyTable
#  ---> Using cache
#  ---> b3338020a96f
# Step 5/12 : RUN pip install bokeh
#  ---> Using cache
#  ---> fc18e4764595
# Step 6/12 : RUN apt-get update   && apt-get install -y --no-install-recommends graphviz libgraphviz-dev pkg-config   && rm -rf /var/lib/apt/lists/*   && pip install pygraphviz
#  ---> Using cache
#  ---> bf299137e714
# Step 7/12 : ENV PATH="/opt/ml/code:${PATH}"
#  ---> Using cache
#  ---> b2a3ebb1e60d
# Step 8/12 : COPY container-training/train.py /opt/ml/code/train.py
#  ---> Using cache
#  ---> 3c90111696b9
# Step 9/12 : COPY container-training/inference.py /opt/ml/code/inference.py
#  ---> Using cache
#  ---> 6844e1ddc80a
# Step 10/12 : RUN pip install seaborn
#  ---> Using cache
#  ---> c1a639b721a8
# Step 11/12 : ENV SAGEMAKER_SUBMIT_DIRECTORY /opt/ml/code
#  ---> Using cache
#  ---> 518266e5f795
# Step 12/12 : ENV SAGEMAKER_PROGRAM train.py
#  ---> Using cache
#  ---> 585b635ecf90
# Successfully built 585b635ecf90
# Successfully tagged autogluon-sagemaker-training-pdt:latest
# The push refers to repository [057716757052.dkr.ecr.ap-northeast-2.amazonaws.com/autogluon-sagemaker-training-pdt]
#
# dd70889b: Preparing
# b57e74da: Preparing
# 2df02a94: Preparing
# e5bdf6e7: Preparing
# d057c38d: Preparing
# 8a548a43: Preparing
# c43e511c: Preparing
# 6fe3b4fb: Preparing
# 94763e92: Preparing
# dad077dd: Preparing
# 8d40f51f: Preparing
# 91740503: Preparing
# 06963fdb: Preparing
# 7c8af503: Preparing
# da04967b: Preparing
# 4d2f8170: Preparing
# d309bc2e: Preparing
# 6bab84f0: Preparing
# 60933a99: Preparing
# 40a5867e: Preparing
# d43b0774: Preparing
# 62d5f9b3: Preparing
# 90c5c0a5: Preparing
# 3a32fcfb: Preparing
# a71ce233: Preparing
# ddf6a67c: Preparing
# 6de3ff64: Preparing
# 7f5e6796: Layer already exists latest: digest: sha256:a484c36ff022ec953fa8cbc69372eb57ac4c43ec540a6c98c3a7dcb5664592be size: 6183
# ##### Build Inference Image ###########
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# Sending build context to Docker daemon  153.4MB
# Step 1/5 : ARG REGISTRY_URI
# Step 2/5 : FROM ${REGISTRY_URI}
#  ---> ac9d36e4dca4
# Step 3/5 : RUN pip install autogluon
#  ---> Using cache
#  ---> 8daf2f4b3204
# Step 4/5 : RUN pip install PrettyTable
#  ---> Using cache
#  ---> fb69e68b26e3
# Step 5/5 : ENV SAGEMAKER_PROGRAM inference.py
#  ---> Using cache
#  ---> 3cd859fd5ee3
# Successfully built 3cd859fd5ee3
# Successfully tagged autogluon-sagemaker-inference-pdt:latest
# The push refers to repository [057716757052.dkr.ecr.ap-northeast-2.amazonaws.com/autogluon-sagemaker-inference-pdt]
#
# e16ff4a2: Preparing
# ad52dc25: Preparing
# 3ff8312b: Preparing
# 59ec0d8a: Preparing
# 12639dc5: Preparing
# 0e9af77f: Preparing
# bdb96df8: Preparing
# 34244b0d: Preparing
# 229eddc1: Preparing
# aceca18a: Preparing
# eee005c5: Preparing
# 2cfcc32d: Preparing
# bf2f5ca8: Preparing
# 1292030a: Preparing
# 8ef677a1: Preparing
# e9af77f: Waiting g
# df18e61b: Preparing
# a71ce233: Preparing
# db96df8: Waiting g
# 6de3ff64: Preparing
# 7f5e6796: Layer already exists latest: digest: sha256:b4911f364e72b1b75bbf035b066df4968d84ce5edf51fec436ff530ae806475a size: 4716

# %% [markdown]
# ## 데이터 로딩

# %% [markdown]
# 기존에 만든 데이터를 로딩하고 합니다. AutoGluon 이용시 별도의 검증(validation)셋의 생성은 필요하지 않습니다. (내부적으로 k-fold cross-validation을 이용합니다.)

# %%
# %store -r no_auto_train_file
# %store -r no_auto_test_file

train = pd.read_csv(no_auto_train_file)
test = pd.read_csv(no_auto_test_file)

# Split test X/y
label = 'classes'
y_test = test[label]
X_test = test.drop(columns=[label])
print("auto_train_file: ", train.shape)
print("auto_test_file: ", test.shape)



from IPython.display import display as dp
dp(train.head(2))
dp(test.head(2))
dp(X_test.head(2))
# Out:
# auto_train_file:  (53740, 18)
# auto_test_file:  (13436, 18)
#    classes  customer_zip_code_prefix customer_city customer_state  price  \
# 0        3                     12030       taubate             SP  29.99
# 1        2                     78075        cuiaba             MT  23.90
#
#    freight_value  product_weight_g product_category_name_english  \
# 0          10.96            9000.0                 fashion_shoes
# 1          26.82            1500.0               furniture_decor
#
#    seller_zip_code_prefix seller_city seller_state  order_weekday  order_day  \
# 0                   13481     limeira           SP              1          4
# 1                   17051       bauru           SP              1          4
#
#    order_month customer_seller_state customer_seller_city  \
# 0           10                 SP_SP      taubate_limeira
# 1           10                 MT_SP         cuiaba_bauru
#
#   customer_seller_zip_code_prefix  product_volume
# 0                     12030_13481          2640.0
# 1                     78075_17051         14625.0
#    classes  customer_zip_code_prefix customer_city customer_state   price  \
# 0        3                     89219     joinville             SC  105.00
# 1        0                      9950       diadema             SP   99.97
#
#    freight_value  product_weight_g product_category_name_english  \
# 0          23.89            1000.0                 watches_gifts
# 1          15.80             650.0                    housewares
#
#    seller_zip_code_prefix     seller_city seller_state  order_weekday  \
# 0                   21840  rio de janeiro           RJ              1
# 1                   32677           betim           MG              1
#
#    order_day  order_month customer_seller_state      customer_seller_city  \
# 0         19            6                 SC_RJ  joinville_rio de janeiro
# 1         19            6                 SP_MG             diadema_betim
#
#   customer_seller_zip_code_prefix  product_volume
# 0                     89219_21840          7632.0
# 1                      9950_32677          9600.0
#    customer_zip_code_prefix customer_city customer_state   price  \
# 0                     89219     joinville             SC  105.00
# 1                      9950       diadema             SP   99.97
#
#    freight_value  product_weight_g product_category_name_english  \
# 0          23.89            1000.0                 watches_gifts
# 1          15.80             650.0                    housewares
#
#    seller_zip_code_prefix     seller_city seller_state  order_weekday  \
# 0                   21840  rio de janeiro           RJ              1
# 1                   32677           betim           MG              1
#
#    order_day  order_month customer_seller_state      customer_seller_city  \
# 0         19            6                 SC_RJ  joinville_rio de janeiro
# 1         19            6                 SP_MG             diadema_betim
#
#   customer_seller_zip_code_prefix  product_volume
# 0                     89219_21840          7632.0
# 1                      9950_32677          9600.0

# %% [markdown]
# #### 훈련과 테스트 파일을 S3에 업로드

# %%
from p_utils import upload_s3

# Upload train. test file
data_prefix = 'autogluon/predict-deliver-time/data'

train_s3_path = upload_s3(bucket, no_auto_train_file, data_prefix)
test_s3_path = upload_s3(bucket, no_auto_test_file, data_prefix)
print("train_s3_path: ", train_s3_path)
print("test_s3_path: ", test_s3_path)
# Out:
# train_s3_path:  s3://sagemaker-ap-northeast-2-057716757052/autogluon/predict-deliver-time/data/preproc_data/auto_no_fe/train/train.csv
# test_s3_path:  s3://sagemaker-ap-northeast-2-057716757052/autogluon/predict-deliver-time/data/preproc_data/auto_no_fe/test/test.csv

# %% [markdown]
# ## 하이퍼 파라미터를 설정
# 실제 훈련을 하기 전에 훈련 이미지에 (훈련 코드 + 프레임워크 (MXNET, AutoGluon)) 파리미터를 제공 합니다.
# - 가장 중요한 파라미터는 아래와 같습니다.
#     - label에 현재 데이터 셋의 레이블 컬럼을 입력해야 합니다.
#     - ```fit_args``` 은 autogluon.task.TabularPrediction.fit() 인자로 제공이 됩니다.
#     - presets은 모델이 '배포에 최적화' 하도록 파라미터 값을 제공 합니다.
#     - feature_importance: 추론후에 피쳐의 중요성을 프린트 합니다. (훈련 로그 참조)
# ```
# fit_args = {
#   'label': 'classes',
#   # Adding 'best_quality' to presets list will result in better performance (but longer runtime)
#   'presets': ['optimize_for_deployment'],
# }
# hyperparameters = {
#   'fit_args': fit_args,
#   'feature_importance': True
# }
# ```
#
#
#
# ### 하이퍼파라미터 선택
# 추가 하이퍼 파라미터는 여기를 보세요.
# - fit 파라미터
#     - [fit parameters](https://autogluon.mxnet.io/api/autogluon.task.html?highlight=eval_metric#autogluon.task.TabularPrediction.fit)
# - [Predicting Columns in a Table - In Depth](https://autogluon.mxnet.io/tutorials/tabular_prediction/tabular-indepth.html#model-ensembling-with-stacking-bagging).
# - 가장 최소한의 파라미터 세팅은 타겟 레이블만 세팅하는  `fit_args['label']` 입니다.
# - 아래 추가로 사용할 파라미터는 참조 하세요
#
# ```python
# nn_options = {
#     'num_epochs': "10",
#     'learning_rate': "ag.space.Real(1e-4, 1e-2, default=5e-4, log=True)",
#     'activation': "ag.space.Categorical('relu', 'softrelu', 'tanh')",
#     'layers': "ag.space.Categorical([100],[1000],[200,100],[300,200,100])",
#     'dropout_prob': "ag.space.Real(0.0, 0.5, default=0.1)"
# }
#
# gbm_options = {
#     'num_boost_round': "100",
#     'num_leaves': "ag.space.Int(lower=26, upper=66, default=36)"
# }
#
# model_hps = {'NN': nn_options, 'GBM': gbm_options}
#
# fit_args = {
#   'label': 'y',
#   'presets': ['best_quality', 'optimize_for_deployment'],
#   'time_limits': 60*10,
#   'hyperparameters': model_hps,
#   'hyperparameter_tune': True,
#   'search_strategy': 'skopt'
# }
#
# hyperparameters = {
#   'fit_args': fit_args,
#   'feature_importance': True
# }
# ```
# **Note:** Your hyperparameter choices may affect the size of the model package, which could result in additional time taken to upload your model and complete training. Including `'optimize_for_deployment'` in the list of `fit_args['presets']` is recommended to greatly reduce upload times.
#
# <br>

# %%
# Define required label and optional additional parameters
fit_args = {
  'label': 'classes',
  # Adding 'best_quality' to presets list will result in better performance (but longer runtime)
  'presets': ['optimize_for_deployment'],
}

# Pass fit_args to SageMaker estimator hyperparameters
hyperparameters = {
  'fit_args': fit_args,
  'feature_importance': True
}

tags = [{
    'Key' : 'AlgorithmName',
    'Value' : 'AutoGluon-Tabular'
}]

# %% [markdown]
# ## 훈련
# 훈련에는 로컬 모드와 세이지 메이커의 클라우드 클러스터에서 실행할 수 있습니다. 처음 실행시에는 **로컬 모드** 를 사용 하세요. 시간이 절약 됩니다. 아래의 코드를 주석 처리하면서 로컬 모드, 세이지 메이커 호스팅 모드로 바꾸세요.
#
# ```
# instance_type = 'local' # 로컬 모드
# # instance_type = 'ml.m5.2xlarge'
# ```
#
# **Note:** 모델에서 필요로 하는 데이터에 `train_volume_size`를 조절 하세요.

# %%
# %%time

# instance_type = 'ml.m5.2xlarge'
instance_type = 'local'

ecr_image = f'{ecr_uri_prefix}/{training_algorithm_name}:latest'

estimator = Estimator(image_uri=ecr_image,
                      role=role,
                      instance_count=1,
                      instance_type=instance_type,
                      hyperparameters=hyperparameters,
                      volume_size=100,
                      tags=tags)

# Set inputs. Test data is optional, but requires a label column.
inputs = {'training': train_s3_path, 'testing': test_s3_path}
# Out:
# CPU times: user 8.46 ms, sys: 136 µs, total: 8.6 ms
# Wall time: 8.38 ms

# %%
# %%time
estimator.fit(inputs)
# Out:
# Creating tmpqhbwd2co_algo-1-5cx7t_1 ...
# Attaching to tmpqhbwd2co_algo-1-5cx7t_12mdone
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,545 sagemaker-training-toolkit INFO     Imported framework sagemaker_mxnet_container.training
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,548 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,548 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'classes', 'presets': ['optimize_for_deployment']} to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,548 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,558 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_HOSTS': '["algo-1-5cx7t"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"feature_importance":"True","fit_args":"{\'label\': \'classes\', \'presets\': [\'optimize_for_deployment\']}"}', 'SM_USER_ENTRY_POINT': 'train.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1-5cx7t","hosts":["algo-1-5cx7t"]}', 'SM_INPUT_DATA_CONFIG': '{"testing":{"TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["testing","training"]', 'SM_CURRENT_HOST': 'algo-1-5cx7t', 'SM_MODULE_NAME': 'train', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '72', 'SM_NUM_GPUS': '0', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': '/opt/ml/code', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"testing":"/opt/ml/input/data/testing","training":"/opt/ml/input/data/training"},"current_host":"algo-1-5cx7t","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1-5cx7t"],"hyperparameters":{"feature_importance":"True","fit_args":"{\'label\': \'classes\', \'presets\': [\'optimize_for_deployment\']}"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"testing":{"TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"autogluon-sagemaker-training-pdt-2021-02-03-04-13-24-971","log_level":20,"master_hostname":"algo-1-5cx7t","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":72,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-5cx7t","hosts":["algo-1-5cx7t"]},"user_entry_point":"train.py"}', 'SM_USER_ARGS': '["--feature_importance","True","--fit_args","{\'label\': \'classes\', \'presets\': [\'optimize_for_deployment\']}"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_CHANNEL_TESTING': '/opt/ml/input/data/testing', 'SM_HP_FIT_ARGS': "{'label': 'classes', 'presets': ['optimize_for_deployment']}", 'SM_HP_FEATURE_IMPORTANCE': 'True'}
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,560 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,561 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'classes', 'presets': ['optimize_for_deployment']} to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,561 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,575 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,575 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'classes', 'presets': ['optimize_for_deployment']} to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,576 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,587 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,587 sagemaker-training-toolkit INFO     Failed to parse hyperparameter fit_args value {'label': 'classes', 'presets': ['optimize_for_deployment']} to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,588 sagemaker-training-toolkit INFO     Failed to parse hyperparameter feature_importance value True to Json.
# algo-1-5cx7t_1  | Returning the value itself
# algo-1-5cx7t_1  | 2021-02-03 04:13:29,610 sagemaker-training-toolkit INFO     Invoking user script
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | Training Env:
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | {
# algo-1-5cx7t_1  |     "additional_framework_parameters": {},
# algo-1-5cx7t_1  |     "channel_input_dirs": {
# algo-1-5cx7t_1  |         "training": "/opt/ml/input/data/training",
# algo-1-5cx7t_1  |         "testing": "/opt/ml/input/data/testing"
# algo-1-5cx7t_1  |     },
# algo-1-5cx7t_1  |     "current_host": "algo-1-5cx7t",
# algo-1-5cx7t_1  |     "framework_module": "sagemaker_mxnet_container.training:main",
# algo-1-5cx7t_1  |     "hosts": [
# algo-1-5cx7t_1  |         "algo-1-5cx7t"
# algo-1-5cx7t_1  |     ],
# algo-1-5cx7t_1  |     "hyperparameters": {
# algo-1-5cx7t_1  |         "fit_args": "{'label': 'classes', 'presets': ['optimize_for_deployment']}",
# algo-1-5cx7t_1  |         "feature_importance": "True"
# algo-1-5cx7t_1  |     },
# algo-1-5cx7t_1  |     "input_config_dir": "/opt/ml/input/config",
# algo-1-5cx7t_1  |     "input_data_config": {
# algo-1-5cx7t_1  |         "training": {
# algo-1-5cx7t_1  |             "TrainingInputMode": "File"
# algo-1-5cx7t_1  |         },
# algo-1-5cx7t_1  |         "testing": {
# algo-1-5cx7t_1  |             "TrainingInputMode": "File"
# algo-1-5cx7t_1  |         }
# algo-1-5cx7t_1  |     },
# algo-1-5cx7t_1  |     "input_dir": "/opt/ml/input",
# algo-1-5cx7t_1  |     "is_master": true,
# algo-1-5cx7t_1  |     "job_name": "autogluon-sagemaker-training-pdt-2021-02-03-04-13-24-971",
# algo-1-5cx7t_1  |     "log_level": 20,
# algo-1-5cx7t_1  |     "master_hostname": "algo-1-5cx7t",
# algo-1-5cx7t_1  |     "model_dir": "/opt/ml/model",
# algo-1-5cx7t_1  |     "module_dir": "/opt/ml/code",
# algo-1-5cx7t_1  |     "module_name": "train",
# algo-1-5cx7t_1  |     "network_interface_name": "eth0",
# algo-1-5cx7t_1  |     "num_cpus": 72,
# algo-1-5cx7t_1  |     "num_gpus": 0,
# algo-1-5cx7t_1  |     "output_data_dir": "/opt/ml/output/data",
# algo-1-5cx7t_1  |     "output_dir": "/opt/ml/output",
# algo-1-5cx7t_1  |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# algo-1-5cx7t_1  |     "resource_config": {
# algo-1-5cx7t_1  |         "current_host": "algo-1-5cx7t",
# algo-1-5cx7t_1  |         "hosts": [
# algo-1-5cx7t_1  |             "algo-1-5cx7t"
# algo-1-5cx7t_1  |         ]
# algo-1-5cx7t_1  |     },
# algo-1-5cx7t_1  |     "user_entry_point": "train.py"
# algo-1-5cx7t_1  | }
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | Environment variables:
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | SM_HOSTS=["algo-1-5cx7t"]
# algo-1-5cx7t_1  | SM_NETWORK_INTERFACE_NAME=eth0
# algo-1-5cx7t_1  | SM_HPS={"feature_importance":"True","fit_args":"{'label': 'classes', 'presets': ['optimize_for_deployment']}"}
# algo-1-5cx7t_1  | SM_USER_ENTRY_POINT=train.py
# algo-1-5cx7t_1  | SM_FRAMEWORK_PARAMS={}
# algo-1-5cx7t_1  | SM_RESOURCE_CONFIG={"current_host":"algo-1-5cx7t","hosts":["algo-1-5cx7t"]}
# algo-1-5cx7t_1  | SM_INPUT_DATA_CONFIG={"testing":{"TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}}
# algo-1-5cx7t_1  | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# algo-1-5cx7t_1  | SM_CHANNELS=["testing","training"]
# algo-1-5cx7t_1  | SM_CURRENT_HOST=algo-1-5cx7t
# algo-1-5cx7t_1  | SM_MODULE_NAME=train
# algo-1-5cx7t_1  | SM_LOG_LEVEL=20
# algo-1-5cx7t_1  | SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# algo-1-5cx7t_1  | SM_INPUT_DIR=/opt/ml/input
# algo-1-5cx7t_1  | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# algo-1-5cx7t_1  | SM_OUTPUT_DIR=/opt/ml/output
# algo-1-5cx7t_1  | SM_NUM_CPUS=72
# algo-1-5cx7t_1  | SM_NUM_GPUS=0
# algo-1-5cx7t_1  | SM_MODEL_DIR=/opt/ml/model
# algo-1-5cx7t_1  | SM_MODULE_DIR=/opt/ml/code
# algo-1-5cx7t_1  | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"testing":"/opt/ml/input/data/testing","training":"/opt/ml/input/data/training"},"current_host":"algo-1-5cx7t","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1-5cx7t"],"hyperparameters":{"feature_importance":"True","fit_args":"{'label': 'classes', 'presets': ['optimize_for_deployment']}"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"testing":{"TrainingInputMode":"File"},"training":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"autogluon-sagemaker-training-pdt-2021-02-03-04-13-24-971","log_level":20,"master_hostname":"algo-1-5cx7t","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"train","network_interface_name":"eth0","num_cpus":72,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-5cx7t","hosts":["algo-1-5cx7t"]},"user_entry_point":"train.py"}
# algo-1-5cx7t_1  | SM_USER_ARGS=["--feature_importance","True","--fit_args","{'label': 'classes', 'presets': ['optimize_for_deployment']}"]
# algo-1-5cx7t_1  | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# algo-1-5cx7t_1  | SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# algo-1-5cx7t_1  | SM_CHANNEL_TESTING=/opt/ml/input/data/testing
# algo-1-5cx7t_1  | SM_HP_FIT_ARGS={'label': 'classes', 'presets': ['optimize_for_deployment']}
# algo-1-5cx7t_1  | SM_HP_FEATURE_IMPORTANCE=True
# algo-1-5cx7t_1  | PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | Invoking script with the following command:
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | /usr/local/bin/python3.6 train.py --feature_importance True --fit_args {'label': 'classes', 'presets': ['optimize_for_deployment']}
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | DEBUG AutoGluon version : 0.0.15
# algo-1-5cx7t_1  | /opt/ml/input:
# algo-1-5cx7t_1  | total 8
# algo-1-5cx7t_1  | drwxrwxr-x 2 500 500 4096 Feb  3 04:13 config
# algo-1-5cx7t_1  | drwx------ 4 500 500 4096 Feb  3 04:13 data
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | /opt/ml/input/config:
# algo-1-5cx7t_1  | total 12
# algo-1-5cx7t_1  | -rw-rw-r-- 1 500 500 106 Feb  3 04:13 hyperparameters.json
# algo-1-5cx7t_1  | -rw-rw-r-- 1 500 500  85 Feb  3 04:13 inputdataconfig.json
# algo-1-5cx7t_1  | -rw-rw-r-- 1 500 500  59 Feb  3 04:13 resourceconfig.json
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | /opt/ml/input/data:
# algo-1-5cx7t_1  | total 8
# algo-1-5cx7t_1  | drwx------ 2 500 500 4096 Feb  3 04:13 testing
# algo-1-5cx7t_1  | drwx------ 2 500 500 4096 Feb  3 04:13 training
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | /opt/ml/input/data/testing:
# algo-1-5cx7t_1  | total 1668
# algo-1-5cx7t_1  | -rw-rw-r-- 1 500 500 1706447 Feb  3 04:13 test.csv
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | /opt/ml/input/data/training:
# algo-1-5cx7t_1  | total 6672
# algo-1-5cx7t_1  | -rw-rw-r-- 1 500 500 6829986 Feb  3 04:13 train.csv
# algo-1-5cx7t_1  | 0
# algo-1-5cx7t_1  | fit_args:
# algo-1-5cx7t_1  | label,  type: <class 'str'>,  value: classes
# algo-1-5cx7t_1  | presets,  type: <class 'list'>,  value: ['optimize_for_deployment']
# algo-1-5cx7t_1  | Train files: ['train.csv']
# algo-1-5cx7t_1  | Beginning AutoGluon training ...
# algo-1-5cx7t_1  | AutoGluon will save models to /opt/ml/model/
# algo-1-5cx7t_1  | AutoGluon Version:  0.0.15
# algo-1-5cx7t_1  | Train Data Rows:    53740
# algo-1-5cx7t_1  | Train Data Columns: 17
# algo-1-5cx7t_1  | Preprocessing data ...
# algo-1-5cx7t_1  | AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# algo-1-5cx7t_1  | 	5 unique label values:  [3, 2, 4, 1, 0]
# algo-1-5cx7t_1  | 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# algo-1-5cx7t_1  | Train Data Class Count: 5
# algo-1-5cx7t_1  | Using Feature Generators to preprocess the data ...
# algo-1-5cx7t_1  | Fitting AutoMLPipelineFeatureGenerator...
# algo-1-5cx7t_1  | 	Available Memory:                    125566.2 MB
# algo-1-5cx7t_1  | 	Train Data (Original)  Memory Usage: 32.79 MB (0.0% of available memory)
# algo-1-5cx7t_1  | 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# algo-1-5cx7t_1  | 	Stage 1 Generators:
# algo-1-5cx7t_1  | 		Fitting AsTypeFeatureGenerator...
# algo-1-5cx7t_1  | 	Stage 2 Generators:
# algo-1-5cx7t_1  | 		Fitting FillNaFeatureGenerator...
# algo-1-5cx7t_1  | 	Stage 3 Generators:
# algo-1-5cx7t_1  | 		Fitting IdentityFeatureGenerator...
# algo-1-5cx7t_1  | 		Fitting CategoryFeatureGenerator...
# algo-1-5cx7t_1  | 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# algo-1-5cx7t_1  | 	Stage 4 Generators:
# algo-1-5cx7t_1  | 		Fitting DropUniqueFeatureGenerator...
# algo-1-5cx7t_1  | 	Types of features in original data (raw dtype, special dtypes):
# algo-1-5cx7t_1  | 		('float', [])  : 4 | ['price', 'freight_value', 'product_weight_g', 'product_volume']
# algo-1-5cx7t_1  | 		('int', [])    : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# algo-1-5cx7t_1  | 		('object', []) : 8 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# algo-1-5cx7t_1  | 	Types of features in processed data (raw dtype, special dtypes):
# algo-1-5cx7t_1  | 		('category', []) : 8 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# algo-1-5cx7t_1  | 		('float', [])    : 4 | ['price', 'freight_value', 'product_weight_g', 'product_volume']
# algo-1-5cx7t_1  | 		('int', [])      : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# algo-1-5cx7t_1  | 	0.5s = Fit runtime
# algo-1-5cx7t_1  | 	17 features in original data used to generate 17 features in processed data.
# algo-1-5cx7t_1  | 	Train Data (Processed) Memory Usage: 5.71 MB (0.0% of available memory)
# algo-1-5cx7t_1  | Data preprocessing and feature engineering runtime = 0.59s ...
# algo-1-5cx7t_1  | AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# algo-1-5cx7t_1  | 	To change this, specify the eval_metric argument of fit()
# algo-1-5cx7t_1  | AutoGluon will early stop models using evaluation metric: 'accuracy'
# algo-1-5cx7t_1  | Fitting model: NeuralNetClassifier ...
# algo-1-5cx7t_1  | 	0.4488	 = Validation accuracy score
# algo-1-5cx7t_1  | 	189.09s	 = Training runtime
# algo-1-5cx7t_1  | 	2.27s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: KNeighborsClassifierUnif ...
# algo-1-5cx7t_1  | 	0.3244	 = Validation accuracy score
# algo-1-5cx7t_1  | 	0.07s	 = Training runtime
# algo-1-5cx7t_1  | 	0.12s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: KNeighborsClassifierDist ...
# algo-1-5cx7t_1  | 	0.3216	 = Validation accuracy score
# algo-1-5cx7t_1  | 	0.07s	 = Training runtime
# algo-1-5cx7t_1  | 	0.12s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: RandomForestClassifierGini ...
# algo-1-5cx7t_1  | 	0.4388	 = Validation accuracy score
# algo-1-5cx7t_1  | 	2.05s	 = Training runtime
# algo-1-5cx7t_1  | 	0.23s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: RandomForestClassifierEntr ...
# algo-1-5cx7t_1  | 	0.4464	 = Validation accuracy score
# algo-1-5cx7t_1  | 	2.86s	 = Training runtime
# algo-1-5cx7t_1  | 	0.22s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: ExtraTreesClassifierGini ...
# algo-1-5cx7t_1  | 	0.4284	 = Validation accuracy score
# algo-1-5cx7t_1  | 	1.38s	 = Training runtime
# algo-1-5cx7t_1  | 	0.23s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: ExtraTreesClassifierEntr ...
# algo-1-5cx7t_1  | 	0.4248	 = Validation accuracy score
# algo-1-5cx7t_1  | 	1.6s	 = Training runtime
# algo-1-5cx7t_1  | 	0.23s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: LightGBMClassifier ...
# algo-1-5cx7t_1  | 	0.4524	 = Validation accuracy score
# algo-1-5cx7t_1  | 	1.8s	 = Training runtime
# algo-1-5cx7t_1  | 	0.03s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: LightGBMClassifierXT ...
# algo-1-5cx7t_1  | 	0.4544	 = Validation accuracy score
# algo-1-5cx7t_1  | 	1.29s	 = Training runtime
# algo-1-5cx7t_1  | 	0.03s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: CatboostClassifier ...
# algo-1-5cx7t_1  | 	0.4548	 = Validation accuracy score
# algo-1-5cx7t_1  | 	9.91s	 = Training runtime
# algo-1-5cx7t_1  | 	0.09s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: LightGBMClassifierCustom ...
# algo-1-5cx7t_1  | 	0.4556	 = Validation accuracy score
# algo-1-5cx7t_1  | 	3.72s	 = Training runtime
# algo-1-5cx7t_1  | 	0.03s	 = Validation runtime
# algo-1-5cx7t_1  | Fitting model: weighted_ensemble_k0_l1 ...
# algo-1-5cx7t_1  | 	0.4736	 = Validation accuracy score
# algo-1-5cx7t_1  | 	0.58s	 = Training runtime
# algo-1-5cx7t_1  | 	0.0s	 = Validation runtime
# algo-1-5cx7t_1  | AutoGluon training complete, total runtime = 240.84s ...
# algo-1-5cx7t_1  | Deleting model KNeighborsClassifierDist. All files under /opt/ml/model/models/KNeighborsClassifierDist/ will be removed.
# algo-1-5cx7t_1  | *** Summary of fit() ***
# algo-1-5cx7t_1  | Estimated performance of each model:
# algo-1-5cx7t_1  |                          model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# algo-1-5cx7t_1  | 0      weighted_ensemble_k0_l1     0.4736       3.478608  214.338538                0.000638           0.575538            1       True         11
# algo-1-5cx7t_1  | 1     LightGBMClassifierCustom     0.4556       0.031311    3.721483                0.031311           3.721483            0       True         10
# algo-1-5cx7t_1  | 2           CatboostClassifier     0.4548       0.091847    9.911842                0.091847           9.911842            0       True          9
# algo-1-5cx7t_1  | 3         LightGBMClassifierXT     0.4544       0.030738    1.291822                0.030738           1.291822            0       True          8
# algo-1-5cx7t_1  | 4           LightGBMClassifier     0.4524       0.030082    1.800934                0.030082           1.800934            0       True          7
# algo-1-5cx7t_1  | 5          NeuralNetClassifier     0.4488       2.271628  189.086878                2.271628         189.086878            0       True          1
# algo-1-5cx7t_1  | 6   RandomForestClassifierEntr     0.4464       0.224871    2.855601                0.224871           2.855601            0       True          4
# algo-1-5cx7t_1  | 7   RandomForestClassifierGini     0.4388       0.229071    2.049125                0.229071           2.049125            0       True          3
# algo-1-5cx7t_1  | 8     ExtraTreesClassifierGini     0.4284       0.226140    1.382905                0.226140           1.382905            0       True          5
# algo-1-5cx7t_1  | 9     ExtraTreesClassifierEntr     0.4248       0.225414    1.595254                0.225414           1.595254            0       True          6
# algo-1-5cx7t_1  | 10    KNeighborsClassifierUnif     0.3244       0.116869    0.067156                0.116869           0.067156            0       True          2
# algo-1-5cx7t_1  | Number of models trained: 11
# algo-1-5cx7t_1  | Types of models trained:
# algo-1-5cx7t_1  | {'KNNModel', 'RFModel', 'WeightedEnsembleModel', 'TabularNeuralNetModel', 'XTModel', 'CatboostModel', 'LGBModel'}
# algo-1-5cx7t_1  | Bagging used: False
# algo-1-5cx7t_1  | Stack-ensembling used: False
# algo-1-5cx7t_1  | Hyperparameter-tuning used: False
# algo-1-5cx7t_1  | User-specified hyperparameters:
# algo-1-5cx7t_1  | {'default': {'NN': [{}], 'GBM': [{}, {'extra_trees': True, 'AG_args': {'name_suffix': 'XT'}}], 'CAT': [{}], 'RF': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'XT': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'KNN': [{'weights': 'uniform', 'AG_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'AG_args': {'name_suffix': 'Dist'}}], 'custom': [{'num_boost_round': 10000, 'num_threads': -1, 'objective': 'multiclass', 'num_classes': 5, 'verbose': -1, 'boosting_type': 'gbdt', 'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'two_round': True, 'seed_value': 0, 'AG_args': {'model_type': 'GBM', 'name_suffix': 'Custom', 'disable_in_hpo': True}}]}}
# algo-1-5cx7t_1  | Feature Metadata (Processed):
# algo-1-5cx7t_1  | (raw dtype, special dtypes):
# algo-1-5cx7t_1  | ('category', []) : 8 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# algo-1-5cx7t_1  | ('float', [])    : 4 | ['price', 'freight_value', 'product_weight_g', 'product_volume']
# algo-1-5cx7t_1  | ('int', [])      : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# algo-1-5cx7t_1  | Plot summary of models saved to file: /opt/ml/model/SummaryOfModels.html
# algo-1-5cx7t_1  | *** End of fit() summary ***
# algo-1-5cx7t_1  | /usr/local/lib/python3.6/site-packages/pygraphviz/agraph.py:1390: RuntimeWarning: Warning: using box for unknown shape rectagle
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  |   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
# algo-1-5cx7t_1  | Test files: ['test.csv']
# algo-1-5cx7t_1  | Running model on test data and getting Leaderboard...
# algo-1-5cx7t_1  | +----------------------------+---------------------+-----------+---------------------+----------------------+---------------------+-------------------------+------------------------+---------------------+-------------+-----------+-----------+
# algo-1-5cx7t_1  | |           model            |      score_test     | score_val |    pred_time_test   |    pred_time_val     |       fit_time      | pred_time_test_marginal | pred_time_val_marginal |  fit_time_marginal  | stack_level | can_infer | fit_order |
# algo-1-5cx7t_1  | +----------------------------+---------------------+-----------+---------------------+----------------------+---------------------+-------------------------+------------------------+---------------------+-------------+-----------+-----------+
# algo-1-5cx7t_1  | |     CatboostClassifier     | 0.45824650193509975 |   0.4548  | 0.14477062225341797 | 0.09184694290161133  |  9.911841630935669  |   0.14477062225341797   |  0.09184694290161133   |  9.911841630935669  |      0      |    True   |     9     |
# algo-1-5cx7t_1  | |    LightGBMClassifierXT    | 0.44291455790413814 |   0.4544  |   0.0438232421875   | 0.030737638473510742 |  1.2918217182159424 |     0.0438232421875     |  0.030737638473510742  |  1.2918217182159424 |      0      |    True   |     8     |
# algo-1-5cx7t_1  | |  LightGBMClassifierCustom  | 0.43822566239952365 |   0.4556  | 0.05793952941894531 |  0.0313112735748291  |  3.7214834690093994 |   0.05793952941894531   |   0.0313112735748291   |  3.7214834690093994 |      0      |    True   |     10    |
# algo-1-5cx7t_1  | | RandomForestClassifierEntr |  0.4371092587079488 |   0.4464  |  0.7866308689117432 | 0.22487139701843262  |  2.8556008338928223 |    0.7866308689117432   |  0.22487139701843262   |  2.8556008338928223 |      0      |    True   |     4     |
# algo-1-5cx7t_1  | |     LightGBMClassifier     |  0.4340577552843108 |   0.4524  | 0.05453681945800781 | 0.030081748962402344 |  1.800933837890625  |   0.05453681945800781   |  0.030081748962402344  |  1.800933837890625  |      0      |    True   |     7     |
# algo-1-5cx7t_1  | |  weighted_ensemble_k0_l1   |  0.4318993748139327 |   0.4736  |  17.338027954101562 |  3.4786081314086914  |  214.33853769302368 |   0.011949777603149414  | 0.0006382465362548828  |  0.575538158416748  |      1      |    True   |     11    |
# algo-1-5cx7t_1  | | RandomForestClassifierGini |  0.4317505209883894 |   0.4388  |  0.8003818988800049 | 0.22907114028930664  |  2.0491254329681396 |    0.8003818988800049   |  0.22907114028930664   |  2.0491254329681396 |      0      |    True   |     3     |
# algo-1-5cx7t_1  | |  ExtraTreesClassifierEntr  |  0.4185025305150342 |   0.4248  |  2.8789474964141846 | 0.22541356086730957  |  1.5952541828155518 |    2.8789474964141846   |  0.22541356086730957   |  1.5952541828155518 |      0      |    True   |     6     |
# algo-1-5cx7t_1  | |  ExtraTreesClassifierGini  | 0.41493003870199463 |   0.4284  |  2.144975423812866  | 0.22613954544067383  |  1.3829050064086914 |    2.144975423812866    |  0.22613954544067383   |  1.3829050064086914 |      0      |    True   |     5     |
# algo-1-5cx7t_1  | |  KNeighborsClassifierUnif  | 0.33737719559392676 |   0.3244  | 0.33100032806396484 | 0.11686897277832031  | 0.06715583801269531 |   0.33100032806396484   |  0.11686897277832031   | 0.06715583801269531 |      0      |    True   |     2     |
# algo-1-5cx7t_1  | |    NeuralNetClassifier     | 0.31921702887764214 |   0.4488  |  10.083071947097778 |   2.27162766456604   |  189.0868775844574  |    10.083071947097778   |    2.27162766456604    |  189.0868775844574  |      0      |    True   |     1     |
# algo-1-5cx7t_1  | +----------------------------+---------------------+-----------+---------------------+----------------------+---------------------+-------------------------+------------------------+---------------------+-------------+-----------+-----------+
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | Feature importance:
# algo-1-5cx7t_1  | Computing raw permutation importance for 17 features on weighted_ensemble_k0_l1 ...
# algo-1-5cx7t_1  | 	113.8s	= Expected runtime
# algo-1-5cx7t_1  | 	113.51s	= Actual runtime
# algo-1-5cx7t_1  |                                  Importance score
# algo-1-5cx7t_1  | Feature
# algo-1-5cx7t_1  | order_weekday                               0.095
# algo-1-5cx7t_1  | customer_seller_state                       0.031
# algo-1-5cx7t_1  | freight_value                               0.027
# algo-1-5cx7t_1  | customer_zip_code_prefix                    0.011
# algo-1-5cx7t_1  | seller_city                                 0.009
# algo-1-5cx7t_1  | customer_city                               0.008
# algo-1-5cx7t_1  | seller_state                                0.006
# algo-1-5cx7t_1  | seller_zip_code_prefix                      0.006
# algo-1-5cx7t_1  | product_weight_g                            0.005
# algo-1-5cx7t_1  | product_category_name_english               0.003
# algo-1-5cx7t_1  | customer_seller_city                        0.003
# algo-1-5cx7t_1  | product_volume                              0.000
# algo-1-5cx7t_1  | order_day                                  -0.001
# algo-1-5cx7t_1  | price                                      -0.001
# algo-1-5cx7t_1  | order_month                                -0.002
# algo-1-5cx7t_1  | customer_seller_zip_code_prefix            -0.002
# algo-1-5cx7t_1  | customer_state                             -0.008
# algo-1-5cx7t_1  | Model export summary:
# algo-1-5cx7t_1  | /opt/ml/model/: ['learner.pkl', 'models', 'SummaryOfModels.html']
# algo-1-5cx7t_1  | /opt/ml/model/models: ['LightGBMClassifier', 'NeuralNetClassifier', 'RandomForestClassifierEntr', 'ExtraTreesClassifierGini', 'LightGBMClassifierXT', 'KNeighborsClassifierUnif', 'RandomForestClassifierGini', 'weighted_ensemble_k0_l1', 'CatboostClassifier', 'ExtraTreesClassifierEntr', 'trainer.pkl', 'LightGBMClassifierCustom']
# algo-1-5cx7t_1  | /opt/ml/model directory size: 5.6G
# algo-1-5cx7t_1  |
# algo-1-5cx7t_1  | Elapsed time: 478.929 seconds. Training Completed!
# algo-1-5cx7t_1  | 2021-02-03 04:21:32,115 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# tmpqhbwd2co_algo-1-5cx7t_1 exited with code 0
# Aborting on container exit...
# Failed to delete: /tmp/tmpqhbwd2co/algo-1-5cx7t Please remove it manually.
# ===== Job Complete =====
# CPU times: user 22min 44s, sys: 8.71 s, total: 22min 52s
# Wall time: 31min 1s

# %% [markdown]
# ### 훈련된 모델의 성능 확인
# 아래는 Jupyter Lab 에서는 동작하지 않습니다. Jupyter를 사용하면 가능합니다.

# %%
from utils.ag_utils import launch_viewer

# %%
from utils.ag_utils import launch_viewer

launch_viewer(is_debug=False)
# Out:
# HTML(value="<b><font size=4 color='#0000ff'>Please choose one training job from the list</font></b>")

# %% [markdown]
# ### 세이지 메이커 모델 생성
#
# 추론 이미지 `ecr_image` 는 위에서 생성한 추론 이미지 입니다.
# - '057716757052.dkr.ecr.ap-northeast-2.amazonaws.com/autogluon-sagemaker-inference-pdt:latest'
#
# ### 모드 옵션
# - 로컬 모드
#     - 여기서는 위에서 사용한 estimator 오브젝트에서 create_model() 함수를 호출하여 세이지 메이커 모델을 생성 합니다.
# - 세이지 메이커 호스팅 모드
#     - sagemaker.Model() 를 호출하고 아래의 파라미터를 사용함
#         - ecr_image: 추론 이미지
#         - model_data: 훈련 후에 모델 아티펙트(에: 's3://sagemaker-ap-northeast-2-057716757052/autogluon-sagemaker-training-pdt-2021-01-17-04-10-37-580/output/model.tar.gz')
#         - role
#         - sagemaker session
#         - predictor_cls
#             - 추론의 입력 데이터에 대해서 직렬화, 역직렬화를 정의한 클래스 임.

# %%
# Create predictor object
class AutoGluonTabularPredictor(Predictor):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, 
                         serializer=CSVSerializer(), 
                         deserializer=StringDeserializer(), **kwargs)

# %%
ecr_image = f'{ecr_uri_prefix}/{inference_algorithm_name}:latest'
print(instance_type)

if instance_type == 'local':
    model = estimator.create_model(image_uri=ecr_image, role=role)
else:
    model_uri = os.path.join(estimator.output_path, estimator._current_job_name, "output", "model.tar.gz")
    model = Model(ecr_image, model_data=model_uri, role=role, sagemaker_session=session, predictor_cls=AutoGluonTabularPredictor)
# Out:
# local

# %% [markdown]
# ## 배치 트랜스폼

# %% [markdown]
# 로컬 모드에서는 `s3://<bucket>/<prefix>/output/` 혹은 `file:///<absolute_local_path>` outputs으로써 설정할 수 있다.

# %%
# output_path = f's3://{bucket}/{prefix}/output/'
# print("output_path: ", output_path)

# transformer = model.transformer(instance_count=1, 
#                                 instance_type=instance_type,
#                                 strategy='MultiRecord',
#                                 max_payload=6,
#                                 max_concurrent_transforms=1,                              
#                                 output_path=output_path)

# transformer.transform(test_s3_path, content_type='text/csv', split_type='Line')
# transformer.wait()

# %%
output_path
# Out:
# 's3://sagemaker-ap-northeast-2-057716757052/sagemaker/autogluon-tabular/output/'

# %%
# !aws s3 ls {output_path}
# !aws s3 cp {output_path} . --recursive
# Out:
#                            PRE autogluon-sagemaker-inference-pdt-2021-02-03-04-44-27-724/
# 2021-02-03 04:12:09      26872 test.csv.out
# download: s3://sagemaker-ap-northeast-2-057716757052/sagemaker/autogluon-tabular/output/autogluon-sagemaker-inference-pdt-2021-02-03-04-44-27-724/test.csv.out to autogluon-sagemaker-inference-pdt-2021-02-03-04-44-27-724/test.csv.out
# download: s3://sagemaker-ap-northeast-2-057716757052/sagemaker/autogluon-tabular/output/test.csv.out to ./test.csv.out

# %% [markdown]
# ### 예측 결과 5개를 보여줌

# %%
! head -n5 test.csv.out
# Out:
# 2
# 2
# 2
# 2
# 2

# %% [markdown]
# ### 실시간 엔드 포인트

# %% [markdown]
# ##### 로컬 모드와 호스팅 모드로 해보세요. 처음에는 로컬 모드로 해보세요

# %%
# instance_type = 'ml.m5.2xlarge'
instance_type = 'local'

predictor = model.deploy(initial_instance_count=1, 
                         instance_type=instance_type)
# Out:
# Attaching to tmp5saif8x9_algo-1-y8cvg_1
# algo-1-y8cvg_1  | Warning: Calling MMS with mxnet-model-server. Please move to multi-model-server.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,188 [INFO ] main com.amazonaws.ml.mms.ModelServer -
# algo-1-y8cvg_1  | MMS Home: /usr/local/lib/python3.6/site-packages
# algo-1-y8cvg_1  | Current directory: /
# algo-1-y8cvg_1  | Temp directory: /home/model-server/tmp
# algo-1-y8cvg_1  | Number of GPUs: 0
# algo-1-y8cvg_1  | Number of CPUs: 72
# algo-1-y8cvg_1  | Max heap size: 27305 M
# algo-1-y8cvg_1  | Python executable: /usr/local/bin/python3.6
# algo-1-y8cvg_1  | Config file: /etc/sagemaker-mms.properties
# algo-1-y8cvg_1  | Inference address: http://0.0.0.0:8080
# algo-1-y8cvg_1  | Management address: http://0.0.0.0:8080
# algo-1-y8cvg_1  | Model Store: /.sagemaker/mms/models
# algo-1-y8cvg_1  | Initial Models: ALL
# algo-1-y8cvg_1  | Log dir: /logs
# algo-1-y8cvg_1  | Metrics dir: /logs
# algo-1-y8cvg_1  | Netty threads: 0
# algo-1-y8cvg_1  | Netty client threads: 0
# algo-1-y8cvg_1  | Default workers per model: 72
# algo-1-y8cvg_1  | Blacklist Regex: N/A
# algo-1-y8cvg_1  | Maximum Response Size: 6553500
# algo-1-y8cvg_1  | Maximum Request Size: 6553500
# algo-1-y8cvg_1  | Preload model: false
# algo-1-y8cvg_1  | Prefer direct buffer: false
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,238 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-9000-model
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,343 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - model_service_worker started with args: --sock-type unix --sock-name /home/model-server/tmp/.mms.sock.9000 --handler sagemaker_mxnet_serving_container.handler_service --model-path /.sagemaker/mms/models/model --model-name model --preload-model false --tmp-dir /home/model-server/tmp
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,344 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Listening on port: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,344 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - [PID] 267
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,344 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - MMS worker started.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,344 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Python runtime: 3.6.10
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,344 [INFO ] main com.amazonaws.ml.mms.wlm.ModelManager - Model model loaded.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,365 [INFO ] main com.amazonaws.ml.mms.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,369 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,368 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.mms.sock.9000
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,444 [INFO ] main com.amazonaws.ml.mms.ModelServer - Inference API bind to: http://0.0.0.0:8080
# algo-1-y8cvg_1  | Model server started.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,450 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,453 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,454 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,455 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,457 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,458 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,459 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,460 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,461 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,462 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,463 [WARN ] pool-2-thread-1 com.amazonaws.ml.mms.metrics.MetricCollector - worker pid is not available yet.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,463 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,464 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,465 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,467 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,468 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,469 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,470 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,471 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,472 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,473 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,474 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,475 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,476 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,477 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,479 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,521 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,521 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,522 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,523 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,523 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,523 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,523 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,523 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,524 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,525 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,525 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,526 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,528 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,529 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,531 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,556 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,556 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,556 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,557 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,557 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:56:58,557 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Connection accepted: /home/model-server/tmp/.mms.sock.9000.
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,070 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,129 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,179 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,213 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,231 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,240 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,242 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,249 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,271 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,274 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,282 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,371 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,374 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,379 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,384 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,399 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,403 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,408 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,417 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,443 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,449 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,454 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,505 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,512 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,513 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,517 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,523 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,526 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,541 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,543 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,544 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,546 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,548 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,555 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,561 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,570 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,586 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,589 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,596 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,599 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,621 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,627 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,627 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,629 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,630 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,633 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,646 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,647 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,653 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,659 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,666 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,681 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,681 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,686 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,714 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,717 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,717 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,725 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,727 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,728 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,731 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,741 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,805 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,806 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,861 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:01,921 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Generating new fontManager, this may take some time...
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,486 [INFO ] pool-1-thread-74 ACCESS_LOG - /172.18.0.1:46622 "GET /ping HTTP/1.1" 200 15
# !algo-1-y8cvg_1  | 2021-02-03 04:57:02,743 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,783 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,786 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4256
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,789 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-26
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,792 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,803 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,826 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4296
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,826 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-4
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,833 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4116
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,834 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-34
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,844 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4125
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,844 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-44
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,850 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,861 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,893 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4179
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,893 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-62
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,901 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,903 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4189
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,903 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-50
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,926 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,943 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4228
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,943 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-72
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,950 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,968 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4252
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,968 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-59
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,971 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,991 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4275
# algo-1-y8cvg_1  | 2021-02-03 04:57:02,991 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-14
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,000 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,013 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4483
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,013 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-27
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,041 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4324
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,041 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-48
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,066 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,081 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,107 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4391
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,107 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-57
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,123 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4593
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,123 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-11
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,146 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,150 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,158 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,167 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,187 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4468
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,187 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-28
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,187 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4657
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,187 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-46
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,193 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,199 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4480
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,200 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-45
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,208 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4491
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,208 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-55
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,209 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,212 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# ...
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,437 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4720
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,437 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-30
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,438 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4718
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,438 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-2
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,444 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,455 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4735
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,455 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-56
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,466 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,470 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4940
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,470 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-65
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,475 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,477 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,486 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,493 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4777
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,493 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-35
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,497 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,501 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4786
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,502 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-29
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,503 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,503 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4973
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,503 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-19
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,504 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,509 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,511 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,513 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4957
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,513 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-22
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,518 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,522 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4806
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,523 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-47
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,527 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,527 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,531 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4817
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,532 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-49
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,539 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4824
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,539 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-33
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,540 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4822
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,540 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,540 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-32
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,544 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4828
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,545 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-17
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,546 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5016
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,546 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-18
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,555 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4838
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,555 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-68
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,561 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,566 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5036
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,566 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-37
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,568 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4849
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,568 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-52
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,571 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,575 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,581 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,588 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4871
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,588 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-6
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,592 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,598 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4885
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,598 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-60
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,601 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4882
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,602 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-1
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,606 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4891
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,607 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-8
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,618 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4899
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,619 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-5
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,623 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,626 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,637 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,649 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4934
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,649 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-31
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,651 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4937
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,651 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-7
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,665 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 4946
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,665 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-61
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,694 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,694 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,720 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5190
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,720 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5190
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,720 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-39
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,720 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-63
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,757 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,770 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,783 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5064
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,783 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-51
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,790 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,796 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5082
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,796 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-12
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,815 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5095
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,815 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-9
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,966 [INFO ] W-9000-model-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Loading model from /.sagemaker/mms/models/model with contents ['learner.pkl', 'model.tar.gz', 'code', 'models', 'MAR-INF', 'SummaryOfModels.html']
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,990 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 5460
# algo-1-y8cvg_1  | 2021-02-03 04:57:03,990 [WARN ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerLifeCycle - attachIOStreams() threadName=W-model-21

# %% [markdown]
# ##### Attach to endpoint (or reattach if kernel was restarted)

# %%
# Select standard or local session based on instance_type
if instance_type == 'local': 
    sess = local_session
else: 
    sess = session

# Attach to endpoint
predictor = AutoGluonTabularPredictor(predictor.endpoint, sagemaker_session=sess)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ##### 입력값을 제공하여 예측 합니다.

# %%
sample = X_test[0:1].to_csv(index=False)
sample
# Out:
# 'customer_zip_code_prefix,customer_city,customer_state,price,freight_value,product_weight_g,product_category_name_english,seller_zip_code_prefix,seller_city,seller_state,order_weekday,order_day,order_month,customer_seller_state,customer_seller_city,customer_seller_zip_code_prefix,product_volume\n89219,joinville,SC,105.0,23.89,1000.0,watches_gifts,21840,rio de janeiro,RJ,1,19,6,SC_RJ,joinville_rio de janeiro,89219_21840,7632.0\n'

# %%
results = predictor.predict(sample)
# Out:
# algo-1-y8cvg_1  | 2021-02-03 05:04:14,790 [INFO ] W-model-44-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Gonsoo Test 01 in transform_fn()
# algo-1-y8cvg_1  | 2021-02-03 05:04:22,751 [INFO ] W-model-44-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Raw Predictoins:
# algo-1-y8cvg_1  | 2021-02-03 05:04:22,751 [INFO ] W-model-44-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle -  [2]
# algo-1-y8cvg_1  | 2021-02-03 05:04:22,751 [INFO ] W-model-44-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Prediction counts: Counter({2: 1})
# algo-1-y8cvg_1  | 2021-02-03 05:04:22,753 [INFO ] W-model-44-stdout com.amazonaws.ml.mms.wlm.WorkerLifeCycle - Elapsed time: 7.963 seconds
# algo-1-y8cvg_1  | 2021-02-03 05:04:22,753 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 7964
# algo-1-y8cvg_1  | 2021-02-03 05:04:22,754 [INFO ] W-9000-model ACCESS_LOG - /172.18.0.1:44754 "POST /invocations HTTP/1.1" 200 7965

# %%
print(results)
# Out:
# 2

# %%
results = predictor.predict(X_test.to_csv(index=False)).splitlines()

# Check output
print(Counter(results))
# Out:
# algo-1-y8cvg_1  | 2021-02-03 04:58:08,644 [INFO ] W-9000-model com.amazonaws.ml.mms.wlm.WorkerThread - Backend response time: 3
# algo-1-y8cvg_1  | 2021-02-03 04:58:08,645 [INFO ] W-9000-model ACCESS_LOG - /172.18.0.1:37434 "POST /invocations HTTP/1.1" 500 12
# Counter({"'utf-8' codec can't decode byte 0xb4 in position 71076: invalid start byte": 1, 'Traceback (most recent call last):': 1, '  File "/usr/local/lib/python3.6/site-packages/sagemaker_inference/transformer.py", line 124, in transform': 1, '    input_data = input_data.decode("utf-8")': 1, "UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb4 in position 71076: invalid start byte": 1})

# %% [markdown]
# ##### 레이블이 있는 테스트 데이터 제공
# Prediction performance metrics 는 엔드포인트 로그에 기록이 됩니다.

# %%
results = predictor.predict(test.to_csv(index=False)).splitlines()

# Check output
print(Counter(results))

# %% [markdown]
# ##### 성능 확인

# %%
y_results = list(map(int, results)) # Convert String to int

# %%
# y_results = np.array(results)

print("accuracy: {}".format(accuracy_score(y_true=y_test, y_pred=y_results)))
print(classification_report(y_true=y_test, y_pred=y_results, digits=6))

# %%
from p_utils import plot_conf_mat


from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

cm = confusion_matrix(y_true= y_test, y_pred= y_results)

plt.figure()
fig, ax = plt.subplots(figsize=(10,5))
plot_conf_mat(cm, 
              classes=['0','1', '2', '3', '4'], 
              title='Confusion Matrix')
plt.show()

# %% [markdown]
# ##### 엔드 포인트 삭제

# %%
predictor.delete_endpoint()
