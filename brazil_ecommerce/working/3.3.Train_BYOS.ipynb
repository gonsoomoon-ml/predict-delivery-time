# %% [markdown]
# # Train Model using BYOS
# - AWS Boto3: create_training_job
#     - https://docs.aws.amazon.com/sagemaker/latest/APIReference/API_CreateTrainingJob.html
# - Step 5: Train a Model
#     - Amazon SageMaker Python SDK, AWS SDK for Python (Boto3) 의 두가지 방법을 통한 모델 훈련 방법
#     - https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-train-model.html
# - How to install external package
#     - https://sagemaker.readthedocs.io/en/stable/frameworks/mxnet/using_mxnet.html#use-third-party-libraries

# %%
# %store -r no_auto_train_file
# %store -r no_auto_test_file

# %%
import sagemaker
from sagemaker import get_execution_role
import json
import os
import boto3
import datetime
import logging
import pandas as pd

# %%
# Project name
project_name = 'predict-deliver-time'
now = datetime.datetime.now
str_time = now().strftime('%Y-%m-%d-%H-%M-%S-%f')[:-3]
# Region
region = boto3.Session().region_name
# Bucket
bucket = sagemaker.Session().default_bucket() 
# role
role = get_execution_role()

train_job_name = project_name + '-'+ str_time

# %%
from utils import upload_s3

# Upload train. test file
data_prefix = 'autogluon/predict-deliver-time/data'
train_file = no_auto_train_file.split('/')[-1] # 파일 이름만 추출
test_file = no_auto_test_file.split('/')[-1]

s3_train_file_path = upload_s3(bucket, no_auto_train_file, data_prefix)
s3_test_file_path = upload_s3(bucket, no_auto_test_file, data_prefix)
print("s3_train_file_path: ", s3_train_file_path)
print("s3_test_file_path: ", s3_test_file_path)
# Out:
# s3_train_file_path:  s3://sagemaker-ap-northeast-2-057716757052/autogluon/predict-deliver-time/data/preproc_data/auto_no_fe/train/train.csv
# s3_test_file_path:  s3://sagemaker-ap-northeast-2-057716757052/autogluon/predict-deliver-time/data/preproc_data/auto_no_fe/test/test.csv

# %%
## Train Rows
df = pd.read_csv(no_auto_train_file)
train_rows = df.shape[0]
train_rows = 500

# %%
## S3 output path
output_prefix = 'autogluon/predict-deliver-time/output'
s3_output_path = 's3://{}/{}/'.format(bucket, output_prefix)
print("s3_output_path: ", s3_output_path)

# Define required label and optional additional parameters
# fit_args = {
#   'label': 'classes',
#   # Adding 'best_quality' to presets list will result in better performance (but longer runtime)
#   'presets': ['optimize_for_deployment'],
# }

hyperparameters = {
    'presets': 'optimize_for_deployment',
    'feature_importance': True,    
#     'train_filename':train_file,
#     'test_filename':test_file, 
#     's3_output' :  s3_output_path,
#    'train_job_name' : train_job_name,
    'label' : 'classes', # label column name
    'train_rows': train_rows  
}
# Out:
# s3_output_path:  s3://sagemaker-ap-northeast-2-057716757052/autogluon/predict-deliver-time/output/

# %%
# Resource Type
instance_type = 'ml.c5.9xlarge'
# instance_type = 'local'

# %%
if instance_type == 'local':
    sess = None
    print("sess: ", sess)
else:
    sess = sagemaker.Session()
    print("sess: ", sess)
# Out:
# sess:  <sagemaker.session.Session object at 0x7ff05503f550>

# %%
# %%time 

from sagemaker.mxnet import MXNet

training_image = '763104351884.dkr.ecr.{}.amazonaws.com/mxnet-training:1.6.0-cpu-py3'.format(region)

mx_estimator = MXNet(
                     entry_point = 'autogluon_train.py',
                     source_dir = 'src',
                     framework_version='1.6.0',
                     py_version='py3',
                     role = role,
                     instance_type = instance_type,
                     instance_count = 1,
                     hyperparameters = hyperparameters,
                     session = sess
                    )

from sagemaker.inputs import TrainingInput

s3_train = TrainingInput(s3_train_file_path, distribution='FullyReplicated') 
s3_test = TrainingInput(s3_test_file_path, distribution='FullyReplicated')
mx_estimator.fit( {'train': s3_train_file_path, 'test': s3_test_file_path})
# Out:
# 2020-11-16 14:16:39 Starting - Starting the training job...
# 2020-11-16 14:16:41 Starting - Launching requested ML instances......
# 2020-11-16 14:18:05 Starting - Preparing the instances for training......
# 2020-11-16 14:18:58 Downloading - Downloading input data
# 2020-11-16 14:18:58 Training - Downloading the training image..2020-11-16 14:19:12,745 sagemaker-training-toolkit INFO     Imported framework sagemaker_mxnet_container.training
# 2020-11-16 14:19:12,747 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:19:12,757 sagemaker_mxnet_container.training INFO     MXNet training environment: {'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"feature_importance":true,"label":"classes","presets":"optimize_for_deployment","train_rows":500}', 'SM_USER_ENTRY_POINT': 'autogluon_train.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["test","train"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'autogluon_train', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_mxnet_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '36', 'SM_NUM_GPUS': '0', 'SM_MODEL_DIR': '/opt/ml/model', 'SM_MODULE_DIR': 's3://sagemaker-ap-northeast-2-057716757052/mxnet-training-2020-11-16-14-16-39-398/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"feature_importance":true,"label":"classes","presets":"optimize_for_deployment","train_rows":500},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"mxnet-training-2020-11-16-14-16-39-398","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/mxnet-training-2020-11-16-14-16-39-398/source/sourcedir.tar.gz","module_name":"autogluon_train","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"autogluon_train.py"}', 'SM_USER_ARGS': '["--feature_importance","True","--label","classes","--presets","optimize_for_deployment","--train_rows","500"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TEST': '/opt/ml/input/data/test', 'SM_CHANNEL_TRAIN': '/opt/ml/input/data/train', 'SM_HP_PRESETS': 'optimize_for_deployment', 'SM_HP_TRAIN_ROWS': '500', 'SM_HP_LABEL': 'classes', 'SM_HP_FEATURE_IMPORTANCE': 'true'}
# 2020-11-16 14:19:13,071 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.6 -m pip install -r requirements.txt
# Collecting PrettyTable
#   Downloading https://files.pythonhosted.org/packages/94/d5/52e48f3bcf66f838d411ad85c3ac9550c2451d082623e2d4d4df7411ed5c/prettytable-2.0.0-py3-none-any.whl
# Collecting autogluon
#   Downloading https://files.pythonhosted.org/packages/91/51/ac91303a2eb3aa90e21056b42edcd1568fd8d971723600b3bc3868776107/autogluon-0.0.14-py3-none-any.whl (622kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/site-packages (from PrettyTable->-r requirements.txt (line 1)) (50.3.2)
# Collecting wcwidth
#   Downloading https://files.pythonhosted.org/packages/59/7c/e39aca596badaf1b78e8f547c807b04dae603a433d3e7a7e04d67f2ef3e5/wcwidth-0.2.5-py2.py3-none-any.whl
# Collecting pytest
#   Downloading https://files.pythonhosted.org/packages/b1/ee/53945d50284906adb1e613fabf2e1b8b25926e8676854bb25b93564c0ce7/pytest-6.1.2-py3-none-any.whl (272kB)
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (4.39.0)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (2.7.2)
# Collecting ConfigSpace<=0.4.10
#   Downloading https://files.pythonhosted.org/packages/42/de/4e8e4f26332fc65404f52baa112defbf822b6738b60bfa6b2993f5c60933/ConfigSpace-0.4.10.tar.gz (882kB)
# Collecting openml
#   Downloading https://files.pythonhosted.org/packages/a4/5d/30ce4d1af609ba389d55654e6a7271619253dbbe7006a33bb20c703f0234/openml-0.11.0.tar.gz (110kB)
# Collecting fastparquet==0.4.1
#   Downloading https://files.pythonhosted.org/packages/28/b9/844e32d0e3739e5695057dff3a3b9f4abc0fcccff466fdaadb8fedb0ee1d/fastparquet-0.4.1.tar.gz (28.6MB)
# Collecting lightgbm<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/d6/4d/99073804bd31f15678f24a79e96981dcbaa840bc9926dfd132e9638d51bb/lightgbm-3.1.0-py2.py3-none-manylinux1_x86_64.whl (1.8MB)
# Collecting distributed>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/88/38/d9f0e31c15de18cb124d1ed33cf9c99c84f05f251ff6767e7573c217725b/distributed-2.30.1-py3-none-any.whl (656kB)
# Collecting scikit-learn<0.24,>=0.22.0
#   Downloading https://files.pythonhosted.org/packages/5c/a1/273def87037a7fb010512bbc5901c31cfddfca8080bc63b42b26e3cc55b3/scikit_learn-0.23.2-cp36-cp36m-manylinux1_x86_64.whl (6.8MB)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (1.16.10)
# Requirement already satisfied: cython in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (0.29.21)
# Collecting pandas<2.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/4d/51/bafcff417cd857bc6684336320863b5e5af280530213ef8f534b6042cfe6/pandas-1.1.4-cp36-cp36m-manylinux1_x86_64.whl (9.5MB)
# Requirement already satisfied: gluoncv<1.0,>=0.5.0 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (2.5)
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/8b/03/be33e89f55866065a02e515c5b319304a801a9f1027a9b311a9b1d1f8dc7/scikit_optimize-0.8.1-py2.py3-none-any.whl (101kB)
# Collecting tornado>=5.0.1
#   Downloading https://files.pythonhosted.org/packages/85/26/e710295dcb4aac62b08f22d07efc899574476db37532159a7f71713cdaf2/tornado-6.1-cp36-cp36m-manylinux2010_x86_64.whl (427kB)
# Collecting pyarrow<=1.0.0
#   Downloading https://files.pythonhosted.org/packages/a1/0a/a89de6d747c4698af128a46398703e3d1889f196478fd94a4e16bd1b5c65/pyarrow-1.0.0-cp36-cp36m-manylinux2014_x86_64.whl (17.2MB)
# Collecting catboost<0.25,>=0.23.0
#   Downloading https://files.pythonhosted.org/packages/52/39/128fff65072c8327371e3c594f3c826d29c85b21cb6485980353b168e0e4/catboost-0.24.2-cp36-none-manylinux1_x86_64.whl (66.1MB)
#
# 2020-11-16 14:19:12 Training - Training image download completed. Training in progress.Collecting Pillow<=6.2.1
#   Downloading https://files.pythonhosted.org/packages/10/5c/0e94e689de2476c4c5e644a3bd223a1c1b9e2bdb7c510191750be74fa786/Pillow-6.2.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
# Requirement already satisfied: cryptography>=2.8 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (3.2.1)
# Collecting scipy>=1.3.3
#   Downloading https://files.pythonhosted.org/packages/c8/89/63171228d5ced148f5ced50305c89e8576ffc695a90b58fe5bb602b910c2/scipy-1.5.4-cp36-cp36m-manylinux1_x86_64.whl (25.9MB)
# Collecting autogluon-contrib-nlp
#   Downloading https://files.pythonhosted.org/packages/b9/dc/30d76d44709cf87e9ae9bc9ed8c9ce1882436427ded27edced390ed2933f/autogluon_contrib_nlp-0.0.1b20201009-py3-none-any.whl (147kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (2.22.0)
# Collecting psutil<=5.7.0,>=5.0.0
#   Downloading https://files.pythonhosted.org/packages/c4/b8/3512f0e93e0db23a71d82485ba256071ebef99b227351f0f5540f744af41/psutil-5.7.0.tar.gz (449kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (1.19.1)
# Collecting dask>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/04/94/b4012c61c09300f4413c58a522a6cc1a212dc4a7f6fe1ba98d67429c089d/dask-2.30.0-py3-none-any.whl (848kB)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /usr/local/lib/python3.6/site-packages (from autogluon->-r requirements.txt (line 2)) (0.8.4)
# Collecting toml
#   Downloading https://files.pythonhosted.org/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl
# Collecting iniconfig
#   Downloading https://files.pythonhosted.org/packages/9b/dd/b3c12c6d707058fa947864b67f0c4e0c39ef8610988d7baea9578f3c48f3/iniconfig-1.1.1-py2.py3-none-any.whl
# Collecting pluggy<1.0,>=0.12
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/site-packages (from pytest->autogluon->-r requirements.txt (line 2)) (20.4)
# Collecting attrs>=17.4.0
#   Downloading https://files.pythonhosted.org/packages/c3/aa/cb45262569fcc047bf070b5de61813724d6726db83259222cd7b4c79821a/attrs-20.3.0-py2.py3-none-any.whl (49kB)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /usr/local/lib/python3.6/site-packages (from pytest->autogluon->-r requirements.txt (line 2)) (2.0.0)
# Collecting py>=1.8.2
#   Downloading https://files.pythonhosted.org/packages/68/0f/41a43535b52a81e4f29e420a151032d26f08b62206840c48d14b70e53376/py-1.9.0-py2.py3-none-any.whl (99kB)
# Requirement already satisfied: pynacl>=1.0.1 in /usr/local/lib/python3.6/site-packages (from paramiko>=2.4->autogluon->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /usr/local/lib/python3.6/site-packages (from paramiko>=2.4->autogluon->-r requirements.txt (line 2)) (3.2.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/site-packages (from ConfigSpace<=0.4.10->autogluon->-r requirements.txt (line 2)) (2.4.7)
# Collecting typing
#   Downloading https://files.pythonhosted.org/packages/05/d9/6eebe19d46bd05360c9a9aae822e67a80f9242aabbfc58b641b957546607/typing-3.7.4.3.tar.gz (78kB)
# Collecting liac-arff>=2.4.0
#   Downloading https://files.pythonhosted.org/packages/6e/43/73944aa5ad2b3185c0f0ba0ee6f73277f2eb51782ca6ccf3e6793caf209a/liac-arff-2.5.0.tar.gz
# Collecting xmltodict
#   Downloading https://files.pythonhosted.org/packages/28/fd/30d5c1d3ac29ce229f6bdc40bbc20b28f716e8b363140c26eff19122d8a5/xmltodict-0.12.0-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/site-packages (from openml->autogluon->-r requirements.txt (line 2)) (2.8.0)
# Collecting numba>=0.28
#   Downloading https://files.pythonhosted.org/packages/48/78/31f620c3469287f4255d9a1054bee713cd3596fda2711c392ce3021b3c98/numba-0.51.2-cp36-cp36m-manylinux2014_x86_64.whl (3.1MB)
# Collecting thrift>=0.11.0
#   Downloading https://files.pythonhosted.org/packages/97/1e/3284d19d7be99305eda145b8aa46b0c33244e4a496ec66440dac19f8274d/thrift-0.13.0.tar.gz (59kB)
# Requirement already satisfied: six in /usr/local/lib/python3.6/site-packages (from fastparquet==0.4.1->autogluon->-r requirements.txt (line 2)) (1.15.0)
# Collecting toolz>=0.8.2
#   Downloading https://files.pythonhosted.org/packages/12/f5/537e55f8ba664ff2a26f26913010fb0fcb98b6bbadc6158af888184fd0b7/toolz-0.11.1-py3-none-any.whl (55kB)
# Collecting zict>=0.1.3
#   Downloading https://files.pythonhosted.org/packages/5a/65/0f743c740c30cace984ef8ff96fd1e991083fa884900a8aad3efff3252b9/zict-2.0.0-py3-none-any.whl
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon->-r requirements.txt (line 2)) (1.6.0)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading https://files.pythonhosted.org/packages/20/4d/a7046ae1a1a4cc4e9bbed194c387086f06b25038be596543d026946330c9/sortedcontainers-2.3.0-py2.py3-none-any.whl
# Collecting contextvars; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Collecting tblib>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/f8/cd/2fad4add11c8837e72f50a30e2bda30e67a10d70462f826b291443a55c7d/tblib-1.7.0-py2.py3-none-any.whl
# Collecting msgpack>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/c9/35/33aa1af0700d21beabdf74373f31c52c048be8ee082f98edbc37ba3ae956/msgpack-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (274kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/site-packages (from distributed>=2.6.0->autogluon->-r requirements.txt (line 2)) (5.3.1)
# Collecting click>=6.6
#   Downloading https://files.pythonhosted.org/packages/d2/3d/fa76db83bf75c4f8d338c2fd15c8d33fdd7ad23a9b5e57eb6c5de26b430e/click-7.1.2-py2.py3-none-any.whl (82kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/f7/12/ec3f2e203afa394a149911729357aa48affc59c20e2c1c8297a60f33f133/threadpoolctl-2.1.0-py3-none-any.whl
# Collecting joblib>=0.11
#   Downloading https://files.pythonhosted.org/packages/fc/c9/f58220ac44a1592f79a343caba12f6837f9e0c04c196176a3d66338e1ea8/joblib-0.17.0-py3-none-any.whl (301kB)
# Requirement already satisfied: botocore<1.20.0,>=1.19.10 in /usr/local/lib/python3.6/site-packages (from boto3->autogluon->-r requirements.txt (line 2)) (1.19.10)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/site-packages (from boto3->autogluon->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/site-packages (from boto3->autogluon->-r requirements.txt (line 2)) (0.3.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/site-packages (from pandas<2.0,>=1.0.0->autogluon->-r requirements.txt (line 2)) (2020.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.6/site-packages (from gluoncv<1.0,>=0.5.0->autogluon->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/site-packages (from matplotlib->autogluon->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/site-packages (from matplotlib->autogluon->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: certifi>=2020.06.20 in /usr/local/lib/python3.6/site-packages (from matplotlib->autogluon->-r requirements.txt (line 2)) (2020.6.20)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/site-packages (from networkx<3.0,>=2.3->autogluon->-r requirements.txt (line 2)) (4.4.2)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Collecting plotly
#   Downloading https://files.pythonhosted.org/packages/a6/66/af86e9d9bf1a3e4f2dabebeabd02a32e8ddf671a5d072b3af2b011efea99/plotly-4.12.0-py2.py3-none-any.whl (13.1MB)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/site-packages (from cryptography>=2.8->autogluon->-r requirements.txt (line 2)) (1.14.3)
# Collecting flake8
#   Downloading https://files.pythonhosted.org/packages/d4/ca/3971802ee6251da1abead1a22831d7f4743781e2f743bd266bdd2f46c19b/flake8-3.8.4-py2.py3-none-any.whl (72kB)
# Collecting sacrebleu
#   Downloading https://files.pythonhosted.org/packages/a3/c4/8e948f601a4f9609e8b2b58f31966cb13cf17b940b82aa3e767f01c42c52/sacrebleu-1.4.14-py3-none-any.whl (64kB)
# Collecting tokenizers<0.9.0,>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/e9/ee/fedc3509145ad60fe5b418783f4a4c1b5462a4f0e8c7bbdbda52bdcda486/tokenizers-0.8.1-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
# Collecting regex
#   Downloading https://files.pythonhosted.org/packages/0d/8a/3ac62dadb767ace65a5b954265de4031a99b27148fe14b24771f5c2c2dca/regex-2020.11.13-cp36-cp36m-manylinux2014_x86_64.whl (723kB)
# Collecting yacs>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/38/4f/fe9a4d472aa867878ce3bb7efb16654c5d63672b86dc0e6e953a67018433/yacs-0.1.8-py3-none-any.whl
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/site-packages (from autogluon-contrib-nlp->autogluon->-r requirements.txt (line 2)) (3.13.0)
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/e5/2d/6d4ca4bef9a67070fa1cac508606328329152b1df10bdf31fb6e4e727894/sentencepiece-0.1.94-cp36-cp36m-manylinux2014_x86_64.whl (1.1MB)
# Collecting sacremoses>=0.0.38
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/site-packages (from requests->autogluon->-r requirements.txt (line 2)) (1.25.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/site-packages (from requests->autogluon->-r requirements.txt (line 2)) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/site-packages (from requests->autogluon->-r requirements.txt (line 2)) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest->autogluon->-r requirements.txt (line 2)) (3.4.0)
# Collecting llvmlite<0.35,>=0.34.0.dev0
#   Downloading https://files.pythonhosted.org/packages/f3/b7/8a91b513f165e0affdeb975c1fef307c39d1051ce71e8aec1da9dcb317ad/llvmlite-0.34.0-cp36-cp36m-manylinux2010_x86_64.whl (24.6MB)
# Collecting heapdict
#   Downloading https://files.pythonhosted.org/packages/b6/9d/cd4777dbcf3bef9d9627e0fe4bc43d2e294b1baeb01d0422399d5e9de319/HeapDict-1.0.1-py3-none-any.whl
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/site-packages (from plotly->catboost<0.25,>=0.23.0->autogluon->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->autogluon->-r requirements.txt (line 2)) (2.20)
# Collecting pycodestyle<2.7.0,>=2.6.0a1
#   Downloading https://files.pythonhosted.org/packages/10/5b/88879fb861ab79aef45c7e199cae3ef7af487b5603dcb363517a50602dd7/pycodestyle-2.6.0-py2.py3-none-any.whl (41kB)
# Collecting pyflakes<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/69/5b/fd01b0c696f2f9a6d2c839883b642493b431f28fa32b29abc465ef675473/pyflakes-2.2.0-py2.py3-none-any.whl (66kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading https://files.pythonhosted.org/packages/87/89/479dc97e18549e21354893e4ee4ef36db1d237534982482c3681ee6e7b57/mccabe-0.6.1-py2.py3-none-any.whl
# Installing collected packages: wcwidth, PrettyTable, toml, iniconfig, pluggy, attrs, py, pytest, typing, ConfigSpace, liac-arff, xmltodict, threadpoolctl, joblib, scipy, scikit-learn, pandas, openml, llvmlite, numba, thrift, fastparquet, lightgbm, tornado, psutil, toolz, dask, heapdict, zict, sortedcontainers, immutables, contextvars, tblib, msgpack, click, distributed, pyaml, scikit-optimize, pyarrow, plotly, catboost, Pillow, pycodestyle, pyflakes, mccabe, flake8, sacrebleu, tokenizers, regex, yacs, sentencepiece, sacremoses, autogluon-contrib-nlp, autogluon
#     Running setup.py install for typing: started
#     Running setup.py install for typing: finished with status 'done'
#     Running setup.py install for ConfigSpace: started
#     Running setup.py install for ConfigSpace: finished with status 'done'
#     Running setup.py install for liac-arff: started
#     Running setup.py install for liac-arff: finished with status 'done'
#   Found existing installation: scipy 1.2.2
#     Uninstalling scipy-1.2.2:
#       Successfully uninstalled scipy-1.2.2
#   Found existing installation: scikit-learn 0.20.4
#     Uninstalling scikit-learn-0.20.4:
#       Successfully uninstalled scikit-learn-0.20.4
#   Found existing installation: pandas 0.25.1
#     Uninstalling pandas-0.25.1:
#       Successfully uninstalled pandas-0.25.1
#     Running setup.py install for openml: started
#     Running setup.py install for openml: finished with status 'done'
#     Running setup.py install for thrift: started
#     Running setup.py install for thrift: finished with status 'done'
#     Running setup.py install for fastparquet: started
#     Running setup.py install for fastparquet: finished with status 'done'
#   Found existing installation: psutil 5.7.3
#     Uninstalling psutil-5.7.3:
#       Successfully uninstalled psutil-5.7.3
#     Running setup.py install for psutil: started
#     Running setup.py install for psutil: finished with status 'done'
#     Running setup.py install for contextvars: started
#     Running setup.py install for contextvars: finished with status 'done'
#   Found existing installation: Pillow 8.0.1
#     Uninstalling Pillow-8.0.1:
#       Successfully uninstalled Pillow-8.0.1
#     Running setup.py install for sacremoses: started
#     Running setup.py install for sacremoses: finished with status 'done'
# Successfully installed ConfigSpace-0.4.10 Pillow-6.2.1 PrettyTable-2.0.0 attrs-20.3.0 autogluon-0.0.14 autogluon-contrib-nlp-0.0.1b20201009 catboost-0.24.2 click-7.1.2 contextvars-2.4 dask-2.30.0 distributed-2.30.1 fastparquet-0.4.1 flake8-3.8.4 heapdict-1.0.1 immutables-0.14 iniconfig-1.1.1 joblib-0.17.0 liac-arff-2.5.0 lightgbm-3.1.0 llvmlite-0.34.0 mccabe-0.6.1 msgpack-1.0.0 numba-0.51.2 openml-0.11.0 pandas-1.1.4 plotly-4.12.0 pluggy-0.13.1 psutil-5.7.0 py-1.9.0 pyaml-20.4.0 pyarrow-1.0.0 pycodestyle-2.6.0 pyflakes-2.2.0 pytest-6.1.2 regex-2020.11.13 sacrebleu-1.4.14 sacremoses-0.0.43 scikit-learn-0.23.2 scikit-optimize-0.8.1 scipy-1.5.4 sentencepiece-0.1.94 sortedcontainers-2.3.0 tblib-1.7.0 threadpoolctl-2.1.0 thrift-0.13.0 tokenizers-0.8.1 toml-0.10.2 toolz-0.11.1 tornado-6.1 typing-3.7.4.3 wcwidth-0.2.5 xmltodict-0.12.0 yacs-0.1.8 zict-2.0.0
# WARNING: You are using pip version 19.3.1; however, version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# 2020-11-16 14:20:39,249 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:20:39,261 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:20:39,273 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-11-16 14:20:39,283 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "test": "/opt/ml/input/data/test",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_mxnet_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "presets": "optimize_for_deployment",
#         "train_rows": 500,
#         "label": "classes",
#         "feature_importance": true
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "test": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "mxnet-training-2020-11-16-14-16-39-398",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/mxnet-training-2020-11-16-14-16-39-398/source/sourcedir.tar.gz",
#     "module_name": "autogluon_train",
#     "network_interface_name": "eth0",
#     "num_cpus": 36,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "autogluon_train.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"feature_importance":true,"label":"classes","presets":"optimize_for_deployment","train_rows":500}
# SM_USER_ENTRY_POINT=autogluon_train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["test","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=autogluon_train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_mxnet_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=36
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/mxnet-training-2020-11-16-14-16-39-398/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"test":"/opt/ml/input/data/test","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_mxnet_container.training:main","hosts":["algo-1"],"hyperparameters":{"feature_importance":true,"label":"classes","presets":"optimize_for_deployment","train_rows":500},"input_config_dir":"/opt/ml/input/config","input_data_config":{"test":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"mxnet-training-2020-11-16-14-16-39-398","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/mxnet-training-2020-11-16-14-16-39-398/source/sourcedir.tar.gz","module_name":"autogluon_train","network_interface_name":"eth0","num_cpus":36,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"autogluon_train.py"}
# SM_USER_ARGS=["--feature_importance","True","--label","classes","--presets","optimize_for_deployment","--train_rows","500"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TEST=/opt/ml/input/data/test
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_PRESETS=optimize_for_deployment
# SM_HP_TRAIN_ROWS=500
# SM_HP_LABEL=classes
# SM_HP_FEATURE_IMPORTANCE=true
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python36.zip:/usr/local/lib/python3.6:/usr/local/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /usr/local/bin/python3.6 autogluon_train.py --feature_importance True --label classes --presets optimize_for_deployment --train_rows 500
#
#
# /opt/ml/input:
# total 8
# drwxr-xr-x 2 root root 4096 Nov 16 14:18 config
# drwxr-xr-x 4 root root 4096 Nov 16 14:18 data
#
# /opt/ml/input/config:
# total 32
# -rw-r--r-- 1 root root  204 Nov 16 14:18 debughookconfig.json
# -rw-r--r-- 1 root root  439 Nov 16 14:18 hyperparameters.json
# -rw-r--r-- 1 root root  942 Nov 16 14:18 init-config.json
# -rw-r--r-- 1 root root  206 Nov 16 14:18 inputdataconfig.json
# -rw-r--r-- 1 root root    2 Nov 16 14:18 metric-definition-regex.json
# -rw-r--r-- 1 root root   81 Nov 16 14:18 resourceconfig.json
# -rw-r--r-- 1 root root 2023 Nov 16 14:18 trainingjobconfig.json
# -rw-r--r-- 1 root root    2 Nov 16 14:18 upstreamoutputdataconfig.json
#
# /opt/ml/input/data:
# total 16
# drwxr-xr-x 2 root root 4096 Nov 16 14:18 test
# -rw-r--r-- 1 root root  191 Nov 16 14:18 test-manifest
# drwxr-xr-x 2 root root 4096 Nov 16 14:18 train
# -rw-r--r-- 1 root root  195 Nov 16 14:18 train-manifest
#
# /opt/ml/input/data/test:
# total 1668
# -rw-r--r-- 1 root root 1706447 Nov 16 14:18 test.csv
#
# /opt/ml/input/data/train:
# total 6672
# -rw-r--r-- 1 root root 6829951 Nov 16 14:18 train.csv
# 0
# ######## Display Arguments #########
# model_dir: /opt/ml/model
# train: /opt/ml/input/data/train
# test: /opt/ml/input/data/test
# label: classes
# train_rows: 500
# target: target
# presets: optimize_for_deployment
# feature_importance: True
# Train files: ['train.csv']
# Beginning AutoGluon training ...
# AutoGluon will save models to /opt/ml/model/
# AutoGluon Version:  0.0.14
# Train Data Rows:    500
# Train Data Columns: 17
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# #0115 unique label values:  [2, 3, 1, 0, 4]
# #011If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# #011Available Memory:                    71286.97 MB
# #011Train Data (Original)  Memory Usage: 0.31 MB (0.0% of available memory)
# #011Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# #011Stage 1 Generators:
# #011#011Fitting AsTypeFeatureGenerator...
# #011Stage 2 Generators:
# #011#011Fitting FillNaFeatureGenerator...
# #011Stage 3 Generators:
# #011#011Fitting IdentityFeatureGenerator...
# #011#011Fitting CategoryFeatureGenerator...
# #011#011#011Fitting CategoryMemoryMinimizeFeatureGenerator...
# #011Stage 4 Generators:
# #011#011Fitting DropUniqueFeatureGenerator...
# #011Unused Original Features (Count: 1): ['customer_seller_zip_code_prefix']
# #011#011These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# #011#011Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# #011#011These features do not need to be present at inference time.
# #011#011('object', []) : 1 | ['customer_seller_zip_code_prefix']
# #011Types of features in original data (raw dtype, special dtypes):
# #011#011('float', [])  : 4 | ['price', 'freight_value', 'product_weight_g', 'product_volume']
# #011#011('int', [])    : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# #011#011('object', []) : 7 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# #011Types of features in processed data (raw dtype, special dtypes):
# #011#011('category', []) : 7 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# #011#011('float', [])    : 4 | ['price', 'freight_value', 'product_weight_g', 'product_volume']
# #011#011('int', [])      : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# #0110.1s = Fit runtime
# #01116 features in original data used to generate 16 features in processed data.
# #011Train Data (Processed) Memory Usage: 0.05 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# #011To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'accuracy'
# Fitting model: NeuralNetClassifier ...
# [2020-11-16 14:20:43.962 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-11-16 14:20:43.962 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO hook.py:193] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-11-16 14:20:43.962 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO hook.py:238] Saving to /opt/ml/output/tensors
# [2020-11-16 14:20:43.963 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO state_store.py:67] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2020-11-16 14:20:43.991 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO hook.py:398] Monitoring the collections: losses
# [2020-11-16 14:20:43.991 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO hook.py:461] Hook is writing from the hook with pid: 271
#
# [2020-11-16 14:20:44.027 ip-10-0-67-61.ap-northeast-2.compute.internal:271 WARNING hook.py:978] var is not NDArray or list or tuple of NDArrays, module_name:embednet0 dict
# [2020-11-16 14:20:44.027 ip-10-0-67-61.ap-northeast-2.compute.internal:271 INFO hook.py:236] Registering hook for block softmaxcrossentropyloss2
# /usr/local/lib/python3.6/site-packages/smdebug/core/tfevent/util.py:56: DeprecationWarning: tostring() is deprecated. Use tobytes() instead.
#   dtype=dtype, tensor_content=nparray_data.tostring(), tensor_shape=tps
# /usr/local/lib/python3.6/site-packages/smdebug/mxnet/hook.py:93: UserWarning: "EmbedNet.architecture_desc" is an unregistered container with Blocks. Note that Blocks inside the list, tuple or dict will not be registered automatically. Make sure to register them using register_child() or switching to nn.Sequential/nn.HybridSequential instead.
#   params = block.collect_params().values()
# #0110.32#011 = Validation accuracy score
# #0114.88s#011 = Training runtime
# #0110.03s#011 = Validation runtime
# Fitting model: KNeighborsClassifierUnif ...
# #0110.29#011 = Validation accuracy score
# #0110.01s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: KNeighborsClassifierDist ...
# #0110.3#011 = Validation accuracy score
# #0110.0s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: RandomForestClassifierGini ...
# #0110.38#011 = Validation accuracy score
# #0110.66s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: RandomForestClassifierEntr ...
# #0110.34#011 = Validation accuracy score
# #0110.65s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: ExtraTreesClassifierGini ...
# #0110.28#011 = Validation accuracy score
# #0110.54s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: ExtraTreesClassifierEntr ...
# #0110.3#011 = Validation accuracy score
# #0110.55s#011 = Training runtime
# #0110.11s#011 = Validation runtime
# Fitting model: LightGBMClassifier ...
# #0110.38#011 = Validation accuracy score
# #0110.52s#011 = Training runtime
# #0110.01s#011 = Validation runtime
# Fitting model: LightGBMClassifierXT ...
#
# 2020-11-16 14:21:10 Uploading - Uploading generated training model
# 2020-11-16 14:21:10 Completed - Training job completed
# #0110.43#011 = Validation accuracy score
# #0110.29s#011 = Training runtime
# #0110.01s#011 = Validation runtime
# Fitting model: CatboostClassifier ...
# #0110.43#011 = Validation accuracy score
# #0111.47s#011 = Training runtime
# #0110.01s#011 = Validation runtime
# Fitting model: LightGBMClassifierCustom ...
# #0110.38#011 = Validation accuracy score
# #0111.87s#011 = Training runtime
# #0110.01s#011 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# #0110.43#011 = Validation accuracy score
# #0110.23s#011 = Training runtime
# #0110.0s#011 = Validation runtime
# AutoGluon training complete, total runtime = 13.53s ...
# Deleting model NeuralNetClassifier. All files under /opt/ml/model/models/NeuralNetClassifier/ will be removed.
# Deleting model KNeighborsClassifierUnif. All files under /opt/ml/model/models/KNeighborsClassifierUnif/ will be removed.
# Deleting model KNeighborsClassifierDist. All files under /opt/ml/model/models/KNeighborsClassifierDist/ will be removed.
# Deleting model RandomForestClassifierGini. All files under /opt/ml/model/models/RandomForestClassifierGini/ will be removed.
# Deleting model RandomForestClassifierEntr. All files under /opt/ml/model/models/RandomForestClassifierEntr/ will be removed.
# Deleting model ExtraTreesClassifierGini. All files under /opt/ml/model/models/ExtraTreesClassifierGini/ will be removed.
# Deleting model ExtraTreesClassifierEntr. All files under /opt/ml/model/models/ExtraTreesClassifierEntr/ will be removed.
# Deleting model LightGBMClassifier. All files under /opt/ml/model/models/LightGBMClassifier/ will be removed.
# Deleting model CatboostClassifier. All files under /opt/ml/model/models/CatboostClassifier/ will be removed.
# Deleting model LightGBMClassifierCustom. All files under /opt/ml/model/models/LightGBMClassifierCustom/ will be removed.
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     LightGBMClassifierXT       0.43       0.012666  0.294276                0.012666           0.294276            0       True          1
# 1  weighted_ensemble_k0_l1       0.43       0.014400  0.522758                0.001734           0.228482            1       True          2
# Number of models trained: 2
# Types of models trained:
# {'LGBModel', 'WeightedEnsembleModel'}
# Bagging used: False
# Stack-ensembling used: False
# Hyperparameter-tuning used: False
# User-specified hyperparameters:
# {'default': {'NN': [{}], 'GBM': [{}, {'extra_trees': True, 'AG_args': {'name_suffix': 'XT'}}], 'CAT': [{}], 'RF': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'XT': [{'criterion': 'gini', 'AG_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'AG_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'KNN': [{'weights': 'uniform', 'AG_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'AG_args': {'name_suffix': 'Dist'}}], 'custom': [{'num_boost_round': 10000, 'num_threads': -1, 'objective': 'multiclass', 'num_classes': 5, 'verbose': -1, 'boosting_type': 'gbdt', 'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'two_round': True, 'seed_value': 0, 'AG_args': {'model_type': 'GBM', 'name_suffix': 'Custom', 'disable_in_hpo': True}}]}}
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', []) : 7 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# ('float', [])    : 4 | ['price', 'freight_value', 'product_weight_g', 'product_volume']
# ('int', [])      : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# *** End of fit() summary ***
# Test files: ['test.csv']
# Running model on test data and getting Leaderboard...
# +-------------------------+---------------------+-----------+----------------------+----------------------+---------------------+-------------------------+------------------------+---------------------+-------------+-----------+-----------+
# |          model          |      score_test     | score_val |    pred_time_test    |    pred_time_val     |       fit_time      | pred_time_test_marginal | pred_time_val_marginal |  fit_time_marginal  | stack_level | can_infer | fit_order |
# +-------------------------+---------------------+-----------+----------------------+----------------------+---------------------+-------------------------+------------------------+---------------------+-------------+-----------+-----------+
# |   LightGBMClassifierXT  | 0.40704078594819887 |    0.43   | 0.022190332412719727 | 0.01266622543334961  | 0.29427599906921387 |   0.022190332412719727  |  0.01266622543334961   | 0.29427599906921387 |      0      |    True   |     1     |
# | weighted_ensemble_k0_l1 | 0.40704078594819887 |    0.43   | 0.024080514907836914 | 0.014400482177734375 |  0.5227575302124023 |  0.0018901824951171875  | 0.0017342567443847656  | 0.22848153114318848 |      1      |    True   |     2     |
# +-------------------------+---------------------+-----------+----------------------+----------------------+---------------------+-------------------------+------------------------+---------------------+-------------+-----------+-----------+
#
# Feature importance:
# Computing raw permutation importance for 17 features on weighted_ensemble_k0_l1 ...
# #0110.71s#011= Expected runtime
# #0110.7s#011= Actual runtime
# order_weekday                      0.042
# seller_zip_code_prefix             0.034
# freight_value                      0.032
# customer_seller_state              0.017
# customer_zip_code_prefix           0.011
# customer_state                     0.005
# product_volume                     0.004
# order_day                          0.003
# seller_state                       0.000
# customer_seller_zip_code_prefix    0.000
# customer_seller_city               0.000
# customer_city                      0.000
# seller_city                        0.000
# order_month                       -0.003
# product_category_name_english     -0.004
# product_weight_g                  -0.013
# price                             -0.016
# dtype: float64
# Model export summary:
# /opt/ml/model/: ['models', 'learner.pkl']
# /opt/ml/model/models: ['weighted_ensemble_k0_l1', 'LightGBMClassifierXT', 'trainer.pkl']
# /opt/ml/model directory size: 196K
#
# #### Package Inference Codes ####
# 2020-11-16 14:20:58,373 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 147
# Billable seconds: 147
# CPU times: user 663 ms, sys: 34.7 ms, total: 698 ms
# Wall time: 4min 43s

# %% [markdown]
# ## Create Model

# %%
# # Create predictor object
# from sagemaker.predictor import RealTimePredictor, csv_serializer, StringDeserializer

# class AutoGluonTabularPredictor(RealTimePredictor):
#     def __init__(self, *args, **kwargs):
#         super().__init__(*args, content_type='text/csv', 
#                          serializer=csv_serializer, 
#                          deserializer=StringDeserializer(), **kwargs)

# %%
# from sagemaker.mxnet import MXNetModel

# ## 모델 결과 파일 저장
# # model_artifact='s3://{}/{}/output/model.tar.gz'.format(bucket, train_byos_job_name)
# # print('model_artifact: ', model_artifact)                                                                                                              

# # training_image, inferene_image 가 동일
# inference_image = '763104351884.dkr.ecr.{}.amazonaws.com/mxnet-training:1.6.0-cpu-py3'.format(region)

# if instance_type == 'local':
#     model = mx_estimator.create_model(entry_point = 'src/inference.py',                                          
#                                       role=role)
# else:
#     print("not local")
#     pass
# #     model_uri = os.path.join(estimator.output_path, estimator._current_job_name, "output", "model.tar.gz")
# #     model = Model(model_uri, ecr_image, role=role, sagemaker_session=session, 
# #                   predictor_cls=AutoGluonTabularPredictor)

# %%
# predictor = model.deploy(initial_instance_count=1, 
#                          instance_type=instance_type)

# %%
# from sagemaker import local
# local_session = local.LocalSession()

# %%
# # Select standard or local session based on instance_type
# if instance_type == 'local': 
#     sess = local_session
# else: 
#     sess = session

# # Attach to endpoint
# predictor = AutoGluonTabularPredictor(predictor.endpoint, sagemaker_session=sess)

# %%
# %store -r no_auto_test_file
# test_pd = pd.read_csv(no_auto_test_file)
# label_column = 'classes'
# y_test = test_pd[label_column]
# X_test = test_pd.drop(columns=[label_column])
# X_test = X_test[0:1].to_csv(index=False)
# X_test

# %%
# from sagemaker.serializers import CSVSerializer
# from sagemaker.deserializers import JSONDeserializer
# CSVSerializer.ACCEPT = 'text/csv'
# predictor.serializer = CSVSerializer()
# JSONDeserializer.ACCEPT = 'application/json'
# predictor.deserializer = JSONDeserializer()

# %%
# results = predictor.predict(X_test)

# %%
# results.splitlines()

# %% [markdown]
# ## Store
