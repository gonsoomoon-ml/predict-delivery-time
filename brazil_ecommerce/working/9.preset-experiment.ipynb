# %% [markdown]
# # preset 옵션별 비교
#
#
# - presets = 'medium_quality_faster_train'
#     - 소요시간: 24초
#
# ```
# bash-4.2$ du -h
# 7.5M    ./models/RandomForestClassifierGini
# 156K    ./models/CatboostClassifier
# 7.5M    ./models/RandomForestClassifierEntr
# 224K    ./models/LightGBMClassifierCustom
# 16K     ./models/weighted_ensemble_k0_l1/utils
# 32K     ./models/weighted_ensemble_k0_l1
# 36K     ./models/KNeighborsClassifierDist
# 17M     ./models/ExtraTreesClassifierEntr
# 504K    ./models/LightGBMClassifier
# 488K    ./models/NeuralNetClassifier
# 36K     ./models/KNeighborsClassifierUnif
# 17M     ./models/ExtraTreesClassifierGini
# 48K     ./models/LightGBMClassifierXT
# 51M     ./models
# 84K     ./utils/data
# 88K     ./utils
# 51M     .
# ```
#
# - presets = ['good_quality_faster_inference_only_refit', 'optimize_for_deployment']
#     - 소요시간: 21 분
#
# ```
# bash-4.2$ du -h
# 160K    ./models/LightGBMClassifierXT_FULL_STACKER_l0/LightGBMClassifierXT_FULL
# 168K    ./models/LightGBMClassifierXT_FULL_STACKER_l0
# 536K    ./models/LightGBMClassifier_FULL_STACKER_l0/LightGBMClassifier_FULL
# 544K    ./models/LightGBMClassifier_FULL_STACKER_l0
# 16M     ./models/ExtraTreesClassifierGini_FULL_STACKER_l0/ExtraTreesClassifierGini_FULL
# 16M     ./models/ExtraTreesClassifierGini_FULL_STACKER_l0
# 504K    ./models/NeuralNetClassifier_FULL_STACKER_l0/NeuralNetClassifier_FULL
# 512K    ./models/NeuralNetClassifier_FULL_STACKER_l0
# 17M     ./models/ExtraTreesClassifierEntr_FULL_STACKER_l0/ExtraTreesClassifierEntr_FULL
# 17M     ./models/ExtraTreesClassifierEntr_FULL_STACKER_l0
# 9.0M    ./models/RandomForestClassifierGini_FULL_STACKER_l0/RandomForestClassifierGini_FULL
# 9.0M    ./models/RandomForestClassifierGini_FULL_STACKER_l0
# 192K    ./models/CatboostClassifier_FULL_STACKER_l0/CatboostClassifier_FULL
# 200K    ./models/CatboostClassifier_FULL_STACKER_l0
# 24K     ./models/weighted_ensemble_FULL_k0_l1
# 9.2M    ./models/RandomForestClassifierEntr_FULL_STACKER_l0/RandomForestClassifierEntr_FULL
# 9.2M    ./models/RandomForestClassifierEntr_FULL_STACKER_l0
# 3.3M    ./models/LightGBMClassifierCustom_FULL_STACKER_l0/LightGBMClassifierCustom_FULL
# 3.3M    ./models/LightGBMClassifierCustom_FULL_STACKER_l0
# 56M     ./models
# 56M     .
#
# 아래와 같이 일부 모델은 제거함
#
# Deleting model NeuralNetClassifier_STACKER_l0. All files under deploy_agModels-predictClass/models/NeuralNetClassifier_STACKER_l0/ will be removed.
# Deleting model RandomForestClassifierGini_STACKER_l0. All files under deploy_agModels-predictClass/models/RandomForestClassifierGini_STACKER_l0/ will be removed.
# Deleting model RandomForestClassifierEntr_STACKER_l0. All files under deploy_agModels-predictClass/models/RandomForestClassifierEntr_STACKER_l0/ will be removed.
# Deleting model ExtraTreesClassifierGini_STACKER_l0. All files under deploy_agModels-predictClass/models/ExtraTreesClassifierGini_STACKER_l0/ will be removed.
# Deleting model ExtraTreesClassifierEntr_STACKER_l0. All files under deploy_agModels-predictClass/models/ExtraTreesClassifierEntr_STACKER_l0/ will be removed.
# Deleting model LightGBMClassifier_STACKER_l0. All files under deploy_agModels-predictClass/models/LightGBMClassifier_STACKER_l0/ will be removed.
# Deleting model LightGBMClassifierXT_STACKER_l0. All files under deploy_agModels-predictClass/models/LightGBMClassifierXT_STACKER_l0/ will be removed.
# Deleting model CatboostClassifier_STACKER_l0. All files under deploy_agModels-predictClass/models/CatboostClassifier_STACKER_l0/ will be removed.
# Deleting model LightGBMClassifierCustom_STACKER_l0. All files under deploy_agModels-predictClass/models/LightGBMClassifierCustom_STACKER_l0/ will be removed.
# Deleting model weighted_ensemble_k0_l1. All files under deploy_agModels-predictClass/models/weighted_ensemble_k0_l1/ will be removed.
# ```
#
# - presets = ['optimize_for_deployment']
#     - 소요시간: 21 초
# ```
# bash-4.2$ du -h
# 16K     ./models/weighted_ensemble_k0_l1
# 504K    ./models/LightGBMClassifier
# 528K    ./models
# 568K    .
# ```
#
# - presets = ['best_quality']
#     - 소요시간: 24 분
#     - 사이즈: 5.6 GB
