# %% [markdown]
#  # [Module 2.5] AutoGluon 훈련 및 추론
#
# 이 노트북은 아래와 같은 작업을 합니다.
# - 훈련, 검증 합쳐서 훈련 데이터 생성 (물리적으로 훈련 + 검증)
# - AutoGluon 데이터 타입으로 변경
# - AutoGluon 훈련
# - 테스트 데이터 로딩 및 추론
# - 모델 평가
# - 피쳐 Importance 생성

# %%
# %store -r train_file
# %store -r val_file
# %store -r test_file

# %%
train_file
# Out:
# 'preproc_data/non_feature_engineering/train.csv'

# %%
import autogluon.core as ag
from autogluon.tabular import TabularPrediction as task

# %% [markdown]
# ## 기존 Train, Val을 합쳐서 Train 데이터 생성
# 오토 글루온은 내부적으로 데이터를 다시 훈련, 검증로 나누어서 사용하기에 입력시에 합쳐서 제공 함

# %%
import pandas as pd
from IPython.display import display
import os

def merge_train_val(train_file, val_file, save_file_name):
    train_df = pd.read_csv(train_file)
#     display(train_df.head())
    print('train_df: ', train_df.shape)
    val_df = pd.read_csv(val_file)
#     display(val_df.head())
    print('val_df: ', val_df.shape)    
    train_val_df = pd.concat([train_df, val_df], axis=0)
#     display(train_val_df.head())    
    print('train_val_df: ', train_val_df.shape)   
    train_val_df.to_csv(save_file_name, index=None)
    print(f'{save_file_name} is saved')
    
new_train_val_folder = 'preproc_data/non_feature_engineering/train_val'
os.makedirs(new_train_val_folder, exist_ok=True)
train_val_file_path = os.path.join(new_train_val_folder, 'train_val.csv')
    
merge_train_val(train_file, val_file, train_val_file_path)
# Out:
# train_df:  (47023, 22)
# val_df:  (13435, 22)
# train_val_df:  (60458, 22)
# preproc_data/non_feature_engineering/train_val/train_val.csv is saved

# %% [markdown]
# ## 오토글루온 데이터 타입으로 변경

# %%
train_data = task.Dataset(file_path=train_val_file_path)
subsample_size = train_data.shape[0]
# subsample_size = 500  # subsample subset of data for faster demo, try setting this to much larger values
train_data = train_data.sample(n=subsample_size, random_state=0)
print(train_data.head())
# Out:
#        classes  customer_zip_code_prefix   customer_city customer_state  \
# 49649        4                     85760        capanema             PR
# 14975        4                     36240   santos dumont             MG
# 7275         2                     12312         jacarei             SP
# 28089        4                     20725  rio de janeiro             RJ
# 22946        4                     21221  rio de janeiro             RJ
#
#         price  freight_value  product_weight_g  product_length_cm  \
# 49649   24.99          18.28             237.0               19.0
# 14975  129.90          23.84            2600.0               65.0
# 7275    27.90           8.36             800.0               26.0
# 28089   65.00          16.89            1032.0               17.0
# 22946   49.90          17.09            1400.0               43.0
#
#        product_height_cm  product_width_cm  ...    seller_city  seller_state  \
# 49649                7.0              15.0  ...      bebedouro            SP
# 14975                5.0              45.0  ...       cascavel            PR
# 7275                15.0              22.0  ...      sao paulo            SP
# 28089               15.0              16.0  ...     rio do sul            SC
# 22946                5.0              30.0  ...  tres coracoes            MG
#
#       order_weekday order_day  order_month  customer_seller_state  \
# 49649             4        13            7                  PR_SP
# 14975             6        27            5                  MG_PR
# 7275              5        23            6                  SP_SP
# 28089             2        19            7                  RJ_SC
# 22946             1        17            1                  RJ_MG
#
#                customer_seller_city customer_seller_zip_code_prefix  \
# 49649            capanema_bebedouro                     85760_14709
# 14975        santos dumont_cascavel                     36240_85802
# 7275              jacarei_sao paulo                      12312_4378
# 28089     rio de janeiro_rio do sul                     20725_89160
# 22946  rio de janeiro_tres coracoes                     21221_37410
#
#       te_pdid_mean_smoothed te_pdid_error_smoothed
# 49649              5.988834               1.988834
# 14975              5.988834               1.988834
# 7275               5.740230               3.740230
# 28089            122.614199             118.614199
# 22946             13.815892               9.815892
#
# [5 rows x 22 columns]

# %%
label_column = 'classes'
print("Summary of class variable: \n", train_data[label_column].describe())
# Out:
# Summary of class variable:
#  count    60458.000000
# mean         2.090890
# std          1.152709
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: classes, dtype: float64

# %% [markdown]
# ## 오토글루운으로 훈련

# %%
# %%time
dir = 'agModels-predictClass'  # specifies folder where to store trained models
time_limits = 7200 # seconds
# presets = 'best_quality'
presets = 'medium_quality_faster_train'

predictor = task.fit(train_data=train_data, label=label_column, 
                     output_directory=dir,
                     time_limits=time_limits,
                     presets=presets)
# Out:
# Beginning AutoGluon training ... Time limit = 7200s
# AutoGluon will save models to agModels-predictClass/
# AutoGluon Version:  0.0.15b20201025
# Train Data Rows:    60458
# Train Data Columns: 21
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	5 unique label values:  [4, 2, 1, 0, 3]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# Note: NumExpr detected 36 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# 	Available Memory:                    70185.93 MB
# 	Train Data (Original)  Memory Usage: 38.81 MB (0.1% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 8 | ['price', 'freight_value', 'product_weight_g', 'product_length_cm', 'product_height_cm', ...]
# 		('int', [])    : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# 		('object', []) : 8 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 8 | ['customer_city', 'customer_state', 'product_category_name_english', 'seller_city', 'seller_state', ...]
# 		('float', [])    : 8 | ['price', 'freight_value', 'product_weight_g', 'product_length_cm', 'product_height_cm', ...]
# 		('int', [])      : 5 | ['customer_zip_code_prefix', 'seller_zip_code_prefix', 'order_weekday', 'order_day', 'order_month']
# 	0.8s = Fit runtime
# 	21 features in original data used to generate 21 features in processed data.
# 	Train Data (Processed) Memory Usage: 8.35 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.88s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: 'accuracy'
# Fitting model: NeuralNetClassifier ... Training model for up to 7199.12s of the 7199.12s of remaining time.
# 	0.94	 = Validation accuracy score
# 	410.58s	 = Training runtime
# 	2.28s	 = Validation runtime
# Fitting model: KNeighborsClassifierUnif ... Training model for up to 6786.23s of the 6786.23s of remaining time.
# 	0.3444	 = Validation accuracy score
# 	0.1s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: KNeighborsClassifierDist ... Training model for up to 6785.99s of the 6785.99s of remaining time.
# 	0.3296	 = Validation accuracy score
# 	0.1s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestClassifierGini ... Training model for up to 6785.75s of the 6785.75s of remaining time.
# 	0.6488	 = Validation accuracy score
# 	2.48s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: RandomForestClassifierEntr ... Training model for up to 6779.49s of the 6779.49s of remaining time.
# 	0.6512	 = Validation accuracy score
# 	4.8s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: ExtraTreesClassifierGini ... Training model for up to 6771.05s of the 6771.05s of remaining time.
# 	0.4796	 = Validation accuracy score
# 	1.83s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: ExtraTreesClassifierEntr ... Training model for up to 6757.14s of the 6757.14s of remaining time.
# 	0.4732	 = Validation accuracy score
# 	2.08s	 = Training runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBMClassifier ... Training model for up to 6742.79s of the 6742.79s of remaining time.
# 	0.8804	 = Validation accuracy score
# 	6.95s	 = Training runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBMClassifierXT ... Training model for up to 6735.55s of the 6735.54s of remaining time.
# 	0.6464	 = Validation accuracy score
# 	4.82s	 = Training runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatboostClassifier ... Training model for up to 6730.54s of the 6730.54s of remaining time.
# 	0.8924	 = Validation accuracy score
# 	36.37s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: LightGBMClassifierCustom ... Training model for up to 6694.03s of the 6694.02s of remaining time.
# 	0.8892	 = Validation accuracy score
# 	9.0s	 = Training runtime
# 	0.06s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ... Training model for up to 719.91s of the 6673.41s of remaining time.
# 	0.9464	 = Validation accuracy score
# 	0.65s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 527.33s ...
# CPU times: user 1h 31min 30s, sys: 45min 49s, total: 2h 17min 19s
# Wall time: 8min 47s

# %% [markdown]
# ## 테스트 데이터 로딩

# %%
test_data = task.Dataset(file_path=test_file)
y_test = test_data[label_column]  # values to predict
test_data_nolab = test_data.drop(labels=[label_column],axis=1)  # delete label column to prove we're not cheating
print(test_data_nolab.head())
# Out:
# Loaded data from: preproc_data/non_feature_engineering/test.csv | Columns = 22 / 22 | Rows = 6718 -> 6718
#    customer_zip_code_prefix        customer_city customer_state   price  \
# 0                     12951              atibaia             SP   35.00
# 1                     64016             teresina             PI   21.99
# 2                     37900               passos             MG   69.90
# 3                     71510             brasilia             DF  284.90
# 4                     12244  sao jose dos campos             SP  129.90
#
#    freight_value  product_weight_g  product_length_cm  product_height_cm  \
# 0           8.41             350.0               21.0                9.0
# 1          22.85             300.0               17.0                4.0
# 2          18.59             125.0               20.0               16.0
# 3          18.29             610.0               18.0               12.0
# 4          12.30            1700.0               30.0               35.0
#
#    product_width_cm product_category_name_english  ...           seller_city  \
# 0              13.0                    housewares  ...             sao paulo
# 1              12.0                     telephony  ...             sao paulo
# 2              19.0                 health_beauty  ...             guarulhos
# 3              18.0                consoles_games  ...              cascavel
# 4              25.0                          toys  ...  campo limpo paulista
#
#   seller_state order_weekday  order_day  order_month  customer_seller_state  \
# 0           SP             1         26            6                  SP_SP
# 1           SP             5         12            5                  PI_SP
# 2           SP             6          5            8                  MG_SP
# 3           PR             0         25            6                  DF_PR
# 4           SP             4          5            5                  SP_SP
#
#                        customer_seller_city customer_seller_zip_code_prefix  \
# 0                         atibaia_sao paulo                      12951_4782
# 1                        teresina_sao paulo                      64016_4160
# 2                          passos_guarulhos                      37900_7013
# 3                         brasilia_cascavel                     71510_85804
# 4  sao jose dos campos_campo limpo paulista                     12244_13232
#
#   te_pdid_mean_smoothed  te_pdid_error_smoothed
# 0              6.815892                5.815892
# 1             21.546871               18.546871
# 2             20.265622               17.265622
# 3              6.898432                4.898432
# 4             68.788029               66.788029
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 모델 예측

# %%
predictor = task.load(dir)  # unnecessary, just demonstrates how to load previously-trained predictor from file

prediction = predictor.predict(test_data_nolab)
print("Predictions:  ", prediction)
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=prediction, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.9349508782375707
# Evaluations on test data:
# {
#     "accuracy": 0.9349508782375707,
#     "accuracy_score": 0.9349508782375707,
#     "balanced_accuracy_score": 0.925314584748242,
#     "matthews_corrcoef": 0.9149354029281919
# }
# Detailed (per-class) classification report:
# {
#     "0": {
#         "precision": 0.9828473413379074,
#         "recall": 0.9080824088748018,
#         "f1-score": 0.9439868204283361,
#         "support": 631
#     },
#     "1": {
#         "precision": 0.9433091628213579,
#         "recall": 0.93713163064833,
#         "f1-score": 0.9402102496714849,
#         "support": 1527
#     },
#     "2": {
#         "precision": 0.9191470457574411,
#         "recall": 0.9627733829688228,
#         "f1-score": 0.9404545454545454,
#         "support": 2149
#     },
#     "3": {
#         "precision": 0.9252336448598131,
#         "recall": 0.9292866082603254,
#         "f1-score": 0.9272556977833282,
#         "support": 1598
#     },
#     "4": {
#         "precision": 0.9488188976377953,
#         "recall": 0.8892988929889298,
#         "f1-score": 0.9180952380952381,
#         "support": 813
#     },
#     "accuracy": 0.9349508782375707,
#     "macro avg": {
#         "precision": 0.9438712184828629,
#         "recall": 0.925314584748242,
#         "f1-score": 0.9340005102865865,
#         "support": 6718
#     },
#     "weighted avg": {
#         "precision": 0.9356608951489555,
#         "recall": 0.9349508782375707,
#         "f1-score": 0.934885321040435,
#         "support": 6718
#     }
# }
# Predictions:   [1 3 3 ... 1 4 0]

# %% [markdown]
# ## 리더 보드 생성

# %%
predictor.leaderboard(test_data, silent=True)
# Out:
#                          model  score_test  score_val  pred_time_test  \
# 0      weighted_ensemble_k0_l1    0.934951     0.9464        5.618142
# 1          NeuralNetClassifier    0.922745     0.9400        5.135516
# 2           CatboostClassifier    0.889253     0.8924        0.085054
# 3     LightGBMClassifierCustom    0.884192     0.8892        0.158734
# 4           LightGBMClassifier    0.873325     0.8804        0.193943
# 5   RandomForestClassifierEntr    0.660613     0.6512        0.631125
# 6   RandomForestClassifierGini    0.655403     0.6488        0.966264
# 7         LightGBMClassifierXT    0.647216     0.6464        0.155601
# 8     ExtraTreesClassifierEntr    0.489283     0.4732        2.843774
# 9     ExtraTreesClassifierGini    0.483924     0.4796        2.377401
# 10    KNeighborsClassifierUnif    0.331200     0.3444        0.310886
# 11    KNeighborsClassifierDist    0.323906     0.3296        0.131157
#
#     pred_time_val    fit_time  pred_time_test_marginal  \
# 0        2.482843  463.559869                 0.044895
# 1        2.278328  410.583266                 5.135516
# 2        0.065054   36.372650                 0.085054
# 3        0.057491    8.995554                 0.158734
# 4        0.081055    6.953598                 0.193943
# 5        0.113826    4.796919                 0.631125
# 6        0.114266    2.478532                 0.966264
# 7        0.060677    4.821392                 0.155601
# 8        0.114836    2.082577                 2.843774
# 9        0.115262    1.833099                 2.377401
# 10       0.108601    0.101247                 0.310886
# 11       0.110558    0.095753                 0.131157
#
#     pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                 0.000914           0.654800            1       True
# 1                 2.278328         410.583266            0       True
# 2                 0.065054          36.372650            0       True
# 3                 0.057491           8.995554            0       True
# 4                 0.081055           6.953598            0       True
# 5                 0.113826           4.796919            0       True
# 6                 0.114266           2.478532            0       True
# 7                 0.060677           4.821392            0       True
# 8                 0.114836           2.082577            0       True
# 9                 0.115262           1.833099            0       True
# 10                0.108601           0.101247            0       True
# 11                0.110558           0.095753            0       True
#
#     fit_order
# 0          12
# 1           1
# 2          10
# 3          11
# 4           8
# 5           5
# 6           4
# 7           9
# 8           7
# 9           6
# 10          2
# 11          3

# %% [markdown]
# ## 모델 평가

# %%
from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(y_test, prediction)
f1_score = f1_score(y_test, prediction, average='macro')
print("accuracy: %.2f%%" % accuracy)
print("f1_score: %.2f%%" % f1_score)
# Out:
# accuracy: 0.93%
# f1_score: 0.93%

# %%
from utils import plot_conf_mat


from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

cm = confusion_matrix(y_true= y_test, y_pred= prediction)

plt.figure()
fig, ax = plt.subplots(figsize=(10,5))
plot_conf_mat(cm, 
              classes=['0','1', '2', '3', '4'], 
              title='Confusion Matrix')
plt.show()
# Out:
# [[ 573   52    6    0    0]
#  [   8 1431   88    0    0]
#  [   2   26 2069   48    4]
#  [   0    7   71 1485   35]
#  [   0    1   17   72  723]]

# %% [markdown]
# ## Feature Importance

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

fea_importance = predictor.feature_importance(test_data)

f, ax = plt.subplots(figsize=(10,5))
plot = sns.barplot(x=fea_importance.index, y = fea_importance.values)
# plot = sns.barplot(x=features, y= fea_importance)
ax.set_title('Feature Importance')
plot.set_xticklabels(plot.get_xticklabels(),rotation='vertical')
plt.show()
# Out:
# Computing raw permutation importance for 21 features on weighted_ensemble_k0_l1 ...
# 	30.28s	= Expected runtime
# 	31.06s	= Actual runtime
